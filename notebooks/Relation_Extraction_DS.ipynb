# %% [markdown]
# ## Relation Extraction with Distant Supervision

# %% [markdown]
# <center><img src="data/images/RE_KET.png" width=400 height=300 /></center>

# %% [markdown]
# <center><img src="data/images/RE_DS.png" width=500 height=300 /></center>

# %%
import spacy
import pandas as pd
import rdflib
from rdflib import Graph, Literal, RDF, URIRef
from rdflib.namespace import FOAF , XSD, Namespace

# %% [markdown]
# ### Load Entity Linking Model

# %%
output_dir = './entity_linking_data'
nlp = spacy.load(output_dir + "/trained_el")

# %% [markdown]
# ### Create Relation Extraction Dataset

# %%
dataset = pd.read_csv('./data/starwars_text_dataset.txt', delimiter='\n', header=None, error_bad_lines=False)
dataset.columns = ['text']
dataset
# Out:
# b'Skipping line 341: expected 1 fields, saw 2\nSkipping line 1209: expected 1 fields, saw 2\nSkipping line 3309: expected 1 fields, saw 2\nSkipping line 3615: expected 1 fields, saw 2\nSkipping line 7258: expected 1 fields, saw 2\nSkipping line 8720: expected 1 fields, saw 2\nSkipping line 9514: expected 1 fields, saw 2\nSkipping line 11246: expected 1 fields, saw 2\nSkipping line 12019: expected 1 fields, saw 2\nSkipping line 13450: expected 1 fields, saw 2\nSkipping line 15793: expected 1 fields, saw 2\nSkipping line 16472: expected 1 fields, saw 2\nSkipping line 18440: expected 1 fields, saw 2\nSkipping line 20491: expected 1 fields, saw 2\nSkipping line 21737: expected 1 fields, saw 2\nSkipping line 23946: expected 1 fields, saw 2\nSkipping line 24387: expected 1 fields, saw 2\nSkipping line 24930: expected 1 fields, saw 2\nSkipping line 25723: expected 1 fields, saw 2\nSkipping line 26509: expected 1 fields, saw 2\nSkipping line 27150: expected 1 fields, saw 2\nSkipping line 27152: expected 1 fields, saw 2\nSkipping line 27154: expected 1 fields, saw 2\n'
#                                                     text
# 0      Luke Skywalker is a fictional character and th...
# 1      Portrayed by Mark Hamill, Luke first appeared ...
# 2      Three decades later, Hamill returned as Luke i...
# 3      The Last Jedi (2017), and The Rise of Skywalke...
# 4      He reprised the role in The Mandalorian episod...
# ...                                                  ...
# 25145                                      References ==
# 25146                                                 ==
# 25147                                  External links ==
# 25148  Supreme Leader Snoke in the StarWars.com Databank
# 25149            Snoke on Wookieepedia, a Star Wars wiki
#
# [25150 rows x 1 columns]

# %% [markdown]
# ### Get Relation of Two Entities from KB

# %% [markdown]
# Example: (Luke Skywalker, Anakin Skywalker)

# %%
graph = rdflib.Graph()
graph.parse('./data/starwars-data.ttl', format='turtle')
# Out:
# <Graph identifier=N6018cec5c4aa461b83c1b07d5b2f7fcc (<class 'rdflib.graph.Graph'>)>

# %% [markdown]
# Find path between Luke Skywalker (https://swapi.co/resource/human/1) and Anakin Skywalker (https://swapi.co/resource/human/11)

# %%
query_str = """
    PREFIX rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#>
    PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>
    PREFIX voc: <https://swapi.co/vocabulary/>
    PREFIX xml: <http://www.w3.org/XML/1998/namespace>
    PREFIX xsd: <http://www.w3.org/2001/XMLSchema#>
    PREFIX human: <https://swapi.co/resource/human/>


    SELECT ?s ?p ?o
    WHERE {   
        # ?s ?p ?o.
        VALUES(?s ?p) {
            (human:11 rdfs:label)
            (human:1 rdfs:label)
        }
        
    }
"""
res = graph.query(query_str)
list(res)
# Out:
# [(rdflib.term.URIRef('https://swapi.co/resource/human/1'),
#   rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#label'),
#   rdflib.term.Literal('Luke Skywalker', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string'))),
#  (rdflib.term.URIRef('https://swapi.co/resource/human/11'),
#   rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#label'),
#   rdflib.term.Literal('Anakin Skywalker', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string')))]

# %%
query_str = """
    PREFIX rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#>
    PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>
    PREFIX voc: <https://swapi.co/vocabulary/>
    PREFIX xml: <http://www.w3.org/XML/1998/namespace>
    PREFIX xsd: <http://www.w3.org/2001/XMLSchema#>
    PREFIX human: <https://swapi.co/resource/human/>


    SELECT ?s ?p ?o
    WHERE {   
        # ?s ?p ?o.
        VALUES(?s) {
            (human:11)
        }
        FILTER isIRI(?o)
    }
"""
res = graph.query(query_str)
set(r[-1] for r in res)
# Out:
# {rdflib.term.URIRef('http://commons.wikimedia.org/wiki/Special:FilePath/Anakin%20Skywalker%20costume%20Retouched.jpg'),
#  rdflib.term.URIRef('http://www.wikidata.org/entity/Q51752'),
#  rdflib.term.URIRef('https://swapi.co/resource/film/4'),
#  rdflib.term.URIRef('https://swapi.co/resource/film/5'),
#  rdflib.term.URIRef('https://swapi.co/resource/film/6'),
#  rdflib.term.URIRef('https://swapi.co/resource/planet/1'),
#  rdflib.term.URIRef('https://swapi.co/resource/starship/39'),
#  rdflib.term.URIRef('https://swapi.co/resource/starship/59'),
#  rdflib.term.URIRef('https://swapi.co/resource/starship/65'),
#  rdflib.term.URIRef('https://swapi.co/resource/vehicle/44'),
#  rdflib.term.URIRef('https://swapi.co/resource/vehicle/46'),
#  rdflib.term.URIRef('https://swapi.co/vocabulary/Character'),
#  rdflib.term.URIRef('https://swapi.co/vocabulary/Human')}

# %% [markdown]
# > Degree 2 any human will be connected to any human with human type (predicate)

# %% [markdown]
# > RDF to LPG

# %%
PREFIX : <http://graphtheory/node/>
PREFIX node: <http://graphtheory/node/>

ASK { node:1 :hasNeighbor* node:2 }

# %%
query_str = """
    PREFIX rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#>
    PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>
    PREFIX voc: <https://swapi.co/vocabulary/>
    PREFIX xml: <http://www.w3.org/XML/1998/namespace>
    PREFIX xsd: <http://www.w3.org/2001/XMLSchema#>
    PREFIX human: <https://swapi.co/resource/human/>
    
    ASK {
      human:11 ((<>|!<>)|^(<>|!<>))* human:1
    }
"""
res = graph.query(query_str)
list(res)
# Out:
# [True]

# %%
query_str = """
    PREFIX rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#>
    PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>
    PREFIX voc: <https://swapi.co/vocabulary/>
    PREFIX xml: <http://www.w3.org/XML/1998/namespace>
    PREFIX xsd: <http://www.w3.org/2001/XMLSchema#>
    PREFIX human: <https://swapi.co/resource/human/>
    
    SELECT ?u ?p ?v
    WHERE {
        human:11 ((voc:desc|!voc:desc)|^(voc:desc|!voc:desc))* ?u .
        # ?u ?p ?v .
        # ?v ((voc:desc|!voc:desc)|^(voc:desc|!voc:desc))* human:1 .
    }
"""
res = graph.query(query_str)
list(res)
# Out:
# [(rdflib.term.URIRef('https://swapi.co/resource/planet/1'),
#   rdflib.term.URIRef('https://swapi.co/vocabulary/resident'),
#   rdflib.term.URIRef('https://swapi.co/resource/human/1')),
#  (rdflib.term.URIRef('https://swapi.co/resource/film/1'),
#   rdflib.term.URIRef('https://swapi.co/vocabulary/character'),
#   rdflib.term.URIRef('https://swapi.co/resource/human/1')),
#  (rdflib.term.URIRef('https://swapi.co/resource/film/3'),
#   rdflib.term.URIRef('https://swapi.co/vocabulary/character'),
#   rdflib.term.URIRef('https://swapi.co/resource/human/1')),
#  (rdflib.term.URIRef('https://swapi.co/resource/film/6'),
#   rdflib.term.URIRef('https://swapi.co/vocabulary/character'),
#   rdflib.term.URIRef('https://swapi.co/resource/human/1')),
#  (rdflib.term.URIRef('https://swapi.co/resource/starship/12'),
#   rdflib.term.URIRef('https://swapi.co/vocabulary/pilot'),
#   rdflib.term.URIRef('https://swapi.co/resource/human/1')),
#  (rdflib.term.URIRef('https://swapi.co/resource/starship/22'),
#   rdflib.term.URIRef('https://swapi.co/vocabulary/pilot'),
#   rdflib.term.URIRef('https://swapi.co/resource/human/1')),
#  (rdflib.term.URIRef('https://swapi.co/vocabulary/Human'),
#   rdflib.term.URIRef('https://swapi.co/vocabulary/character'),
#   rdflib.term.URIRef('https://swapi.co/resource/human/1')),
#  (rdflib.term.URIRef('https://swapi.co/resource/film/7'),
#   rdflib.term.URIRef('https://swapi.co/vocabulary/character'),
#   rdflib.term.URIRef('https://swapi.co/resource/human/1')),
#  (rdflib.term.URIRef('https://swapi.co/resource/film/2'),
#   rdflib.term.URIRef('https://swapi.co/vocabulary/character'),
#   rdflib.term.URIRef('https://swapi.co/resource/human/1')),
#  (rdflib.term.URIRef('https://swapi.co/resource/vehicle/30'),
#   rdflib.term.URIRef('https://swapi.co/vocabulary/pilot'),
#   rdflib.term.URIRef('https://swapi.co/resource/human/1')),
#  (rdflib.term.URIRef('https://swapi.co/resource/vehicle/14'),
#   rdflib.term.URIRef('https://swapi.co/vocabulary/pilot'),
#   rdflib.term.URIRef('https://swapi.co/resource/human/1')),
#  (rdflib.term.URIRef('https://swapi.co/resource/human/4'),
#   rdflib.term.URIRef('https://swapi.co/vocabulary/film'),
#   rdflib.term.URIRef('https://swapi.co/resource/film/2')),
#  (rdflib.term.URIRef('https://swapi.co/resource/starship/11'),
#   rdflib.term.URIRef('https://swapi.co/vocabulary/film'),
#   rdflib.term.URIRef('https://swapi.co/resource/film/2')),
#  (rdflib.term.URIRef('https://swapi.co/resource/vehicle/18'),
#   rdflib.term.URIRef('https://swapi.co/vocabulary/film'),
#   rdflib.term.URIRef('https://swapi.co/resource/film/2')),
#  (rdflib.term.URIRef('https://swapi.co/resource/human/1'),
#   rdflib.term.URIRef('https://swapi.co/vocabulary/film'),
#   rdflib.term.URIRef('https://swapi.co/resource/film/2')),
#  (rdflib.term.URIRef('https://swapi.co/resource/droid/3'),
#   rdflib.term.URIRef('https://swapi.co/vocabulary/film'),
#   rdflib.term.URIRef('https://swapi.co/resource/film/2')),
#  (rdflib.term.URIRef('https://swapi.co/vocabulary/Yodasspecies'),
#   rdflib.term.URIRef('https://swapi.co/vocabulary/film'),
#   rdflib.term.URIRef('https://swapi.co/resource/film/2')),
#  (rdflib.term.URIRef('https://swapi.co/resource/starship/12'),
#   rdflib.term.URIRef('https://swapi.co/vocabulary/film'),
#   rdflib.term.URIRef('https://swapi.co/resource/film/2')),
#  (rdflib.term.URIRef('https://swapi.co/resource/vehicle/16'),
#   rdflib.term.URIRef('https://swapi.co/vocabulary/film'),
#   rdflib.term.URIRef('https://swapi.co/resource/film/2')),
#  (rdflib.term.URIRef('https://swapi.co/resource/human/18'),
#   rdflib.term.URIRef('https://swapi.co/vocabulary/film'),
#   rdflib.term.URIRef('https://swapi.co/resource/film/2')),
#  (rdflib.term.URIRef('https://swapi.co/resource/wookiee/13'),
#   rdflib.term.URIRef('https://swapi.co/vocabulary/film'),
#   rdflib.term.URIRef('https://swapi.co/resource/film/2')),
#  (rdflib.term.URIRef('https://swapi.co/resource/starship/22'),
#   rdflib.term.URIRef('https://swapi.co/vocabulary/film'),
#   rdflib.term.URIRef('https://swapi.co/resource/film/2')),
#  (rdflib.term.URIRef('https://swapi.co/resource/planet/27'),
#   rdflib.term.URIRef('https://swapi.co/vocabulary/film'),
#   rdflib.term.URIRef('https://swapi.co/resource/film/2')),
#  (rdflib.term.URIRef('https://swapi.co/resource/human/26'),
#   rdflib.term.URIRef('https://swapi.co/vocabulary/film'),
#   rdflib.term.URIRef('https://swapi.co/resource/film/2')),
#  (rdflib.term.URIRef('https://swapi.co/vocabulary/Human'),
#   rdflib.term.URIRef('https://swapi.co/vocabulary/film'),
#   rdflib.term.URIRef('https://swapi.co/resource/film/2')),
#  (rdflib.term.URIRef('https://swapi.co/vocabulary/Wookiee'),
#   rdflib.term.URIRef('https://swapi.co/vocabulary/film'),
#   rdflib.term.URIRef('https://swapi.co/resource/film/2')),
#  (rdflib.term.URIRef('https://swapi.co/resource/starship/3'),
#   rdflib.term.URIRef('https://swapi.co/vocabulary/film'),
#   rdflib.term.URIRef('https://swapi.co/resource/film/2')),
#  (rdflib.term.URIRef('https://swapi.co/resource/droid/2'),
#   rdflib.term.URIRef('https://swapi.co/vocabulary/film'),
#   rdflib.term.URIRef('https://swapi.co/resource/film/2')),
#  (rdflib.term.URIRef('https://swapi.co/vocabulary/Droid'),
#   rdflib.term.URIRef('https://swapi.co/vocabulary/film'),
#   rdflib.term.URIRef('https://swapi.co/resource/film/2')),
#  (rdflib.term.URIRef('https://swapi.co/resource/starship/10'),
#   rdflib.term.URIRef('https://swapi.co/vocabulary/film'),
#   rdflib.term.URIRef('https://swapi.co/resource/film/2')),
#  (rdflib.term.URIRef('https://swapi.co/resource/human/25'),
#   rdflib.term.URIRef('https://swapi.co/vocabulary/film'),
#   rdflib.term.URIRef('https://swapi.co/resource/film/2')),
#  (rdflib.term.URIRef('https://swapi.co/resource/trandoshan/24'),
#   rdflib.term.URIRef('https://swapi.co/vocabulary/film'),
#   rdflib.term.URIRef('https://swapi.co/resource/film/2')),
#  (rdflib.term.URIRef('https://swapi.co/resource/droid/23'),
#   rdflib.term.URIRef('https://swapi.co/vocabulary/film'),
#   rdflib.term.URIRef('https://swapi.co/resource/film/2')),
#  (rdflib.term.URIRef('https://swapi.co/resource/starship/17'),
#   rdflib.term.URIRef('https://swapi.co/vocabulary/film'),
#   rdflib.term.URIRef('https://swapi.co/resource/film/2')),
#  (rdflib.term.URIRef('https://swapi.co/resource/vehicle/19'),
#   rdflib.term.URIRef('https://swapi.co/vocabulary/film'),
#   rdflib.term.URIRef('https://swapi.co/resource/film/2')),
#  (rdflib.term.URIRef('https://swapi.co/resource/vehicle/8'),
#   rdflib.term.URIRef('https://swapi.co/vocabulary/film'),
#   rdflib.term.URIRef('https://swapi.co/resource/film/2')),
#  (rdflib.term.URIRef('https://swapi.co/resource/human/10'),
#   rdflib.term.URIRef('https://swapi.co/vocabulary/film'),
#   rdflib.term.URIRef('https://swapi.co/resource/film/2')),
#  (rdflib.term.URIRef('https://swapi.co/resource/human/22'),
#   rdflib.term.URIRef('https://swapi.co/vocabulary/film'),
#   rdflib.term.URIRef('https://swapi.co/resource/film/2')),
#  (rdflib.term.URIRef('https://swapi.co/resource/starship/21'),
#   rdflib.term.URIRef('https://swapi.co/vocabulary/film'),
#   rdflib.term.URIRef('https://swapi.co/resource/film/2')),
#  (rdflib.term.URIRef('https://swapi.co/resource/human/5'),
#   rdflib.term.URIRef('https://swapi.co/vocabulary/film'),
#   rdflib.term.URIRef('https://swapi.co/resource/film/2')),
#  (rdflib.term.URIRef('https://swapi.co/resource/starship/23'),
#   rdflib.term.URIRef('https://swapi.co/vocabulary/film'),
#   rdflib.term.URIRef('https://swapi.co/resource/film/2')),
#  (rdflib.term.URIRef('https://swapi.co/resource/planet/6'),
#   rdflib.term.URIRef('https://swapi.co/vocabulary/film'),
#   rdflib.term.URIRef('https://swapi.co/resource/film/2')),
#  (rdflib.term.URIRef('https://swapi.co/resource/vehicle/14'),
#   rdflib.term.URIRef('https://swapi.co/vocabulary/film'),
#   rdflib.term.URIRef('https://swapi.co/resource/film/2')),
#  (rdflib.term.URIRef('https://swapi.co/resource/vehicle/20'),
#   rdflib.term.URIRef('https://swapi.co/vocabulary/film'),
#   rdflib.term.URIRef('https://swapi.co/resource/film/2')),
#  (rdflib.term.URIRef('https://swapi.co/resource/starship/15'),
#   rdflib.term.URIRef('https://swapi.co/vocabulary/film'),
#   rdflib.term.URIRef('https://swapi.co/resource/film/2')),
#  (rdflib.term.URIRef('https://swapi.co/resource/planet/5'),
#   rdflib.term.URIRef('https://swapi.co/vocabulary/film'),
#   rdflib.term.URIRef('https://swapi.co/resource/film/2')),
#  (rdflib.term.URIRef('https://swapi.co/resource/planet/4'),
#   rdflib.term.URIRef('https://swapi.co/vocabulary/film'),
#   rdflib.term.URIRef('https://swapi.co/resource/film/2')),
#  (rdflib.term.URIRef('https://swapi.co/vocabulary/Trandoshan'),
#   rdflib.term.URIRef('https://swapi.co/vocabulary/film'),
#   rdflib.term.URIRef('https://swapi.co/resource/film/2')),
#  (rdflib.term.URIRef('https://swapi.co/resource/human/21'),
#   rdflib.term.URIRef('https://swapi.co/vocabulary/film'),
#   rdflib.term.URIRef('https://swapi.co/resource/film/2')),
#  (rdflib.term.URIRef('https://swapi.co/resource/yodasspecies/20'),
#   rdflib.term.URIRef('https://swapi.co/vocabulary/film'),
#   rdflib.term.URIRef('https://swapi.co/resource/film/2')),
#  (rdflib.term.URIRef('https://swapi.co/resource/human/14'),
#   rdflib.term.URIRef('https://swapi.co/vocabulary/film'),
#   rdflib.term.URIRef('https://swapi.co/resource/film/2')),
#  (rdflib.term.URIRef('https://swapi.co/resource/film/5'),
#   rdflib.term.URIRef('https://swapi.co/vocabulary/character'),
#   rdflib.term.URIRef('https://swapi.co/resource/human/21')),
#  (rdflib.term.URIRef('https://swapi.co/resource/film/3'),
#   rdflib.term.URIRef('https://swapi.co/vocabulary/character'),
#   rdflib.term.URIRef('https://swapi.co/resource/human/21')),
#  (rdflib.term.URIRef('https://swapi.co/resource/film/6'),
#   rdflib.term.URIRef('https://swapi.co/vocabulary/character'),
#   rdflib.term.URIRef('https://swapi.co/resource/human/21')),
#  (rdflib.term.URIRef('https://swapi.co/resource/film/4'),
#   rdflib.term.URIRef('https://swapi.co/vocabulary/character'),
#   rdflib.term.URIRef('https://swapi.co/resource/human/21')),
#  (rdflib.term.URIRef('https://swapi.co/resource/planet/8'),
#   rdflib.term.URIRef('https://swapi.co/vocabulary/resident'),
#   rdflib.term.URIRef('https://swapi.co/resource/human/21')),
#  (rdflib.term.URIRef('https://swapi.co/vocabulary/Human'),
#   rdflib.term.URIRef('https://swapi.co/vocabulary/character'),
#   rdflib.term.URIRef('https://swapi.co/resource/human/21')),
#  (rdflib.term.URIRef('https://swapi.co/resource/film/2'),
#   rdflib.term.URIRef('https://swapi.co/vocabulary/character'),
#   rdflib.term.URIRef('https://swapi.co/resource/human/21')),
#  (rdflib.term.URIRef('https://swapi.co/resource/human/4'),
#   rdflib.term.URIRef('https://swapi.co/vocabulary/film'),
#   rdflib.term.URIRef('https://swapi.co/resource/film/3')),
#  (rdflib.term.URIRef('https://swapi.co/resource/planet/1'),
#   rdflib.term.URIRef('https://swapi.co/vocabulary/film'),
#   rdflib.term.URIRef('https://swapi.co/resource/film/3')),
#  (rdflib.term.URIRef('https://swapi.co/resource/starship/11'),
#   rdflib.term.URIRef('https://swapi.co/vocabulary/film'),
#   rdflib.term.URIRef('https://swapi.co/resource/film/3')),
#  (rdflib.term.URIRef('https://swapi.co/resource/vehicle/24'),
#   rdflib.term.URIRef('https://swapi.co/vocabulary/film'),
#   rdflib.term.URIRef('https://swapi.co/resource/film/3')),
#  (rdflib.term.URIRef('https://swapi.co/resource/planet/9'),
#   rdflib.term.URIRef('https://swapi.co/vocabulary/film'),
#   rdflib.term.URIRef('https://swapi.co/resource/film/3')),
#  (rdflib.term.URIRef('https://swapi.co/resource/vehicle/18'),
#   rdflib.term.URIRef('https://swapi.co/vocabulary/film'),
#   rdflib.term.URIRef('https://swapi.co/resource/film/3')),
#  (rdflib.term.URIRef('https://swapi.co/resource/vehicle/25'),
#   rdflib.term.URIRef('https://swapi.co/vocabulary/film'),
#   rdflib.term.URIRef('https://swapi.co/resource/film/3')),
#  (rdflib.term.URIRef('https://swapi.co/resource/human/1'),
#   rdflib.term.URIRef('https://swapi.co/vocabulary/film'),
#   rdflib.term.URIRef('https://swapi.co/resource/film/3')),
#  (rdflib.term.URIRef('https://swapi.co/resource/droid/3'),
#   rdflib.term.URIRef('https://swapi.co/vocabulary/film'),
#   rdflib.term.URIRef('https://swapi.co/resource/film/3')),
#  (rdflib.term.URIRef('https://swapi.co/resource/planet/8'),
#   rdflib.term.URIRef('https://swapi.co/vocabulary/film'),
#   rdflib.term.URIRef('https://swapi.co/resource/film/3')),
#  (rdflib.term.URIRef('https://swapi.co/resource/sullustan/31'),
#   rdflib.term.URIRef('https://swapi.co/vocabulary/film'),
#   rdflib.term.URIRef('https://swapi.co/resource/film/3')),
#  (rdflib.term.URIRef('https://swapi.co/vocabulary/Ewok'),
#   rdflib.term.URIRef('https://swapi.co/vocabulary/film'),
#   rdflib.term.URIRef('https://swapi.co/resource/film/3')),
#  (rdflib.term.URIRef('https://swapi.co/vocabulary/Yodasspecies'),
#   rdflib.term.URIRef('https://swapi.co/vocabulary/film'),
#   rdflib.term.URIRef('https://swapi.co/resource/film/3')),
#  (rdflib.term.URIRef('https://swapi.co/vocabulary/Hutt'),
#   rdflib.term.URIRef('https://swapi.co/vocabulary/film'),
#   rdflib.term.URIRef('https://swapi.co/resource/film/3')),
#  (rdflib.term.URIRef('https://swapi.co/resource/hutt/16'),
#   rdflib.term.URIRef('https://swapi.co/vocabulary/film'),
#   rdflib.term.URIRef('https://swapi.co/resource/film/3')),
#  (rdflib.term.URIRef('https://swapi.co/resource/starship/12'),
#   rdflib.term.URIRef('https://swapi.co/vocabulary/film'),
#   rdflib.term.URIRef('https://swapi.co/resource/film/3')),
#  (rdflib.term.URIRef('https://swapi.co/resource/vehicle/16'),
#   rdflib.term.URIRef('https://swapi.co/vocabulary/film'),
#   rdflib.term.URIRef('https://swapi.co/resource/film/3')),
#  (rdflib.term.URIRef('https://swapi.co/resource/vehicle/26'),
#   rdflib.term.URIRef('https://swapi.co/vocabulary/film'),
#   rdflib.term.URIRef('https://swapi.co/resource/film/3')),
#  (rdflib.term.URIRef('https://swapi.co/resource/human/18'),
#   rdflib.term.URIRef('https://swapi.co/vocabulary/film'),
#   rdflib.term.URIRef('https://swapi.co/resource/film/3')),
#  (rdflib.term.URIRef('https://swapi.co/resource/wookiee/13'),
#   rdflib.term.URIRef('https://swapi.co/vocabulary/film'),
#   rdflib.term.URIRef('https://swapi.co/resource/film/3')),
#  (rdflib.term.URIRef('https://swapi.co/resource/starship/22'),
#   rdflib.term.URIRef('https://swapi.co/vocabulary/film'),
#   rdflib.term.URIRef('https://swapi.co/resource/film/3')),
#  (rdflib.term.URIRef('https://swapi.co/vocabulary/Human'),
#   rdflib.term.URIRef('https://swapi.co/vocabulary/film'),
#   rdflib.term.URIRef('https://swapi.co/resource/film/3')),
#  (rdflib.term.URIRef('https://swapi.co/vocabulary/Wookiee'),
#   rdflib.term.URIRef('https://swapi.co/vocabulary/film'),
#   rdflib.term.URIRef('https://swapi.co/resource/film/3')),
#  (rdflib.term.URIRef('https://swapi.co/resource/starship/3'),
#   rdflib.term.URIRef('https://swapi.co/vocabulary/film'),
#   rdflib.term.URIRef('https://swapi.co/resource/film/3')),
#  (rdflib.term.URIRef('https://swapi.co/resource/starship/27'),
#   rdflib.term.URIRef('https://swapi.co/vocabulary/film'),
#   rdflib.term.URIRef('https://swapi.co/resource/film/3')),
#  (rdflib.term.URIRef('https://swapi.co/resource/starship/28'),
#   rdflib.term.URIRef('https://swapi.co/vocabulary/film'),
#   rdflib.term.URIRef('https://swapi.co/resource/film/3')),
#  (rdflib.term.URIRef('https://swapi.co/resource/starship/29'),
#   rdflib.term.URIRef('https://swapi.co/vocabulary/film'),
#   rdflib.term.URIRef('https://swapi.co/resource/film/3')),
#  (rdflib.term.URIRef('https://swapi.co/resource/starship/2'),
#   rdflib.term.URIRef('https://swapi.co/vocabulary/film'),
#   rdflib.term.URIRef('https://swapi.co/resource/film/3')),
#  (rdflib.term.URIRef('https://swapi.co/resource/human/28'),
#   rdflib.term.URIRef('https://swapi.co/vocabulary/film'),
#   rdflib.term.URIRef('https://swapi.co/resource/film/3')),
#  (rdflib.term.URIRef('https://swapi.co/resource/droid/2'),
#   rdflib.term.URIRef('https://swapi.co/vocabulary/film'),
#   rdflib.term.URIRef('https://swapi.co/resource/film/3')),
#  (rdflib.term.URIRef('https://swapi.co/vocabulary/Droid'),
#   rdflib.term.URIRef('https://swapi.co/vocabulary/film'),
#   rdflib.term.URIRef('https://swapi.co/resource/film/3')),
#  (rdflib.term.URIRef('https://swapi.co/resource/starship/10'),
#   rdflib.term.URIRef('https://swapi.co/vocabulary/film'),
#   rdflib.term.URIRef('https://swapi.co/resource/film/3')),
#  (rdflib.term.URIRef('https://swapi.co/resource/human/25'),
#   rdflib.term.URIRef('https://swapi.co/vocabulary/film'),
#   rdflib.term.URIRef('https://swapi.co/resource/film/3')),
#  (rdflib.term.URIRef('https://swapi.co/vocabulary/Twilek'),
#   rdflib.term.URIRef('https://swapi.co/vocabulary/film'),
#   rdflib.term.URIRef('https://swapi.co/resource/film/3')),
#  (rdflib.term.URIRef('https://swapi.co/vocabulary/Sullustan'),
#   rdflib.term.URIRef('https://swapi.co/vocabulary/film'),
#   rdflib.term.URIRef('https://swapi.co/resource/film/3')),
#  (rdflib.term.URIRef('https://swapi.co/resource/starship/17'),
#   rdflib.term.URIRef('https://swapi.co/vocabulary/film'),
#   rdflib.term.URIRef('https://swapi.co/resource/film/3')),
#  (rdflib.term.URIRef('https://swapi.co/resource/vehicle/19'),
#   rdflib.term.URIRef('https://swapi.co/vocabulary/film'),
#   rdflib.term.URIRef('https://swapi.co/resource/film/3')),
#  (rdflib.term.URIRef('https://swapi.co/resource/vehicle/8'),
#   rdflib.term.URIRef('https://swapi.co/vocabulary/film'),
#   rdflib.term.URIRef('https://swapi.co/resource/film/3')),
#  (rdflib.term.URIRef('https://swapi.co/resource/human/10'),
#   rdflib.term.URIRef('https://swapi.co/vocabulary/film'),
#   rdflib.term.URIRef('https://swapi.co/resource/film/3')),
#  (rdflib.term.URIRef('https://swapi.co/vocabulary/Moncalamari'),
#   rdflib.term.URIRef('https://swapi.co/vocabulary/film'),
#   rdflib.term.URIRef('https://swapi.co/resource/film/3')),
#  (rdflib.term.URIRef('https://swapi.co/resource/moncalamari/27'),
#   rdflib.term.URIRef('https://swapi.co/vocabulary/film'),
#   rdflib.term.URIRef('https://swapi.co/resource/film/3')),
#  (rdflib.term.URIRef('https://swapi.co/resource/human/22'),
#   rdflib.term.URIRef('https://swapi.co/vocabulary/film'),
#   rdflib.term.URIRef('https://swapi.co/resource/film/3')),
#  (rdflib.term.URIRef('https://swapi.co/resource/vehicle/30'),
#   rdflib.term.URIRef('https://swapi.co/vocabulary/film'),
#   rdflib.term.URIRef('https://swapi.co/resource/film/3')),
#  (rdflib.term.URIRef('https://swapi.co/resource/human/5'),
#   rdflib.term.URIRef('https://swapi.co/vocabulary/film'),
#   rdflib.term.URIRef('https://swapi.co/resource/film/3')),
#  (rdflib.term.URIRef('https://swapi.co/resource/starship/23'),
#   rdflib.term.URIRef('https://swapi.co/vocabulary/film'),
#   rdflib.term.URIRef('https://swapi.co/resource/film/3')),
#  (rdflib.term.URIRef('https://swapi.co/resource/starship/15'),
#   rdflib.term.URIRef('https://swapi.co/vocabulary/film'),
#   rdflib.term.URIRef('https://swapi.co/resource/film/3')),
#  (rdflib.term.URIRef('https://swapi.co/resource/planet/5'),
#   rdflib.term.URIRef('https://swapi.co/vocabulary/film'),
#   rdflib.term.URIRef('https://swapi.co/resource/film/3')),
#  (rdflib.term.URIRef('https://swapi.co/resource/planet/7'),
#   rdflib.term.URIRef('https://swapi.co/vocabulary/film'),
#   rdflib.term.URIRef('https://swapi.co/resource/film/3')),
#  (rdflib.term.URIRef('https://swapi.co/resource/ewok/30'),
#   rdflib.term.URIRef('https://swapi.co/vocabulary/film'),
#   rdflib.term.URIRef('https://swapi.co/resource/film/3')),
#  (rdflib.term.URIRef('https://swapi.co/resource/human/21'),
#   rdflib.term.URIRef('https://swapi.co/vocabulary/film'),
#   rdflib.term.URIRef('https://swapi.co/resource/film/3')),
#  (rdflib.term.URIRef('https://swapi.co/resource/yodasspecies/20'),
#   rdflib.term.URIRef('https://swapi.co/vocabulary/film'),
#   rdflib.term.URIRef('https://swapi.co/resource/film/3')),
#  (rdflib.term.URIRef('https://swapi.co/resource/human/29'),
#   rdflib.term.URIRef('https://swapi.co/vocabulary/film'),
#   rdflib.term.URIRef('https://swapi.co/resource/film/3')),
#  (rdflib.term.URIRef('https://swapi.co/resource/twilek/45'),
#   rdflib.term.URIRef('https://swapi.co/vocabulary/film'),
#   rdflib.term.URIRef('https://swapi.co/resource/film/3')),
#  (rdflib.term.URIRef('https://swapi.co/resource/human/14'),
#   rdflib.term.URIRef('https://swapi.co/vocabulary/film'),
#   rdflib.term.URIRef('https://swapi.co/resource/film/3')),
#  (rdflib.term.URIRef('https://swapi.co/resource/film/3'),
#   rdflib.term.URIRef('https://swapi.co/vocabulary/vehicle'),
#   rdflib.term.URIRef('https://swapi.co/resource/vehicle/30')),
#  (rdflib.term.URIRef('https://swapi.co/resource/human/1'),
#   rdflib.term.URIRef('https://swapi.co/vocabulary/vehicle'),
#   rdflib.term.URIRef('https://swapi.co/resource/vehicle/30')),
#  (rdflib.term.URIRef('https://swapi.co/resource/human/5'),
#   rdflib.term.URIRef('https://swapi.co/vocabulary/vehicle'),
#   rdflib.term.URIRef('https://swapi.co/resource/vehicle/30')),
#  (rdflib.term.URIRef('https://swapi.co/resource/planet/1'),
#   rdflib.term.URIRef('https://swapi.co/vocabulary/resident'),
#   rdflib.term.URIRef('https://swapi.co/resource/human/1')),
#  (rdflib.term.URIRef('https://swapi.co/resource/film/1'),
#   rdflib.term.URIRef('https://swapi.co/vocabulary/character'),
#   rdflib.term.URIRef('https://swapi.co/resource/human/1')),
#  (rdflib.term.URIRef('https://swapi.co/resource/film/3'),
#   rdflib.term.URIRef('https://swapi.co/vocabulary/character'),
#   rdflib.term.URIRef('https://swapi.co/resource/human/1')),
#  (rdflib.term.URIRef('https://swapi.co/resource/film/6'),
#   rdflib.term.URIRef('https://swapi.co/vocabulary/character'),
#   rdflib.term.URIRef('https://swapi.co/resource/human/1')),
#  (rdflib.term.URIRef('https://swapi.co/resource/starship/12'),
#   rdflib.term.URIRef('https://swapi.co/vocabulary/pilot'),
#   rdflib.term.URIRef('https://swapi.co/resource/human/1')),
#  (rdflib.term.URIRef('https://swapi.co/resource/starship/22'),
#   rdflib.term.URIRef('https://swapi.co/vocabulary/pilot'),
#   rdflib.term.URIRef('https://swapi.co/resource/human/1')),
#  (rdflib.term.URIRef('https://swapi.co/vocabulary/Human'),
#   rdflib.term.URIRef('https://swapi.co/vocabulary/character'),
#   rdflib.term.URIRef('https://swapi.co/resource/human/1')),
#  (rdflib.term.URIRef('https://swapi.co/resource/film/7'),
#   rdflib.term.URIRef('https://swapi.co/vocabulary/character'),
#   rdflib.term.URIRef('https://swapi.co/resource/human/1')),
#  (rdflib.term.URIRef('https://swapi.co/resource/film/2'),
#   rdflib.term.URIRef('https://swapi.co/vocabulary/character'),
#   rdflib.term.URIRef('https://swapi.co/resource/human/1')),
#  (rdflib.term.URIRef('https://swapi.co/resource/vehicle/30'),
#   rdflib.term.URIRef('https://swapi.co/vocabulary/pilot'),
#   rdflib.term.URIRef('https://swapi.co/resource/human/1')),
#  (rdflib.term.URIRef('https://swapi.co/resource/vehicle/14'),
#   rdflib.term.URIRef('https://swapi.co/vocabulary/pilot'),
#   rdflib.term.URIRef('https://swapi.co/resource/human/1')),
#  (rdflib.term.URIRef('https://swapi.co/resource/film/1'),
#   rdflib.term.URIRef('https://swapi.co/vocabulary/character'),
#   rdflib.term.URIRef('https://swapi.co/resource/human/5')),
#  (rdflib.term.URIRef('https://swapi.co/resource/film/3'),
#   rdflib.term.URIRef('https://swapi.co/vocabulary/character'),
#   rdflib.term.URIRef('https://swapi.co/resource/human/5')),
#  (rdflib.term.URIRef('https://swapi.co/resource/film/6'),
#   rdflib.term.URIRef('https://swapi.co/vocabulary/character'),
#   rdflib.term.URIRef('https://swapi.co/resource/human/5')),
#  (rdflib.term.URIRef('https://swapi.co/vocabulary/Human'),
#   rdflib.term.URIRef('https://swapi.co/vocabulary/character'),
#   rdflib.term.URIRef('https://swapi.co/resource/human/5')),
#  (rdflib.term.URIRef('https://swapi.co/resource/planet/2'),
#   rdflib.term.URIRef('https://swapi.co/vocabulary/resident'),
#   rdflib.term.URIRef('https://swapi.co/resource/human/5')),
#  (rdflib.term.URIRef('https://swapi.co/resource/film/7'),
#   rdflib.term.URIRef('https://swapi.co/vocabulary/character'),
#   rdflib.term.URIRef('https://swapi.co/resource/human/5')),
#  (rdflib.term.URIRef('https://swapi.co/resource/film/2'),
#   rdflib.term.URIRef('https://swapi.co/vocabulary/character'),
#   rdflib.term.URIRef('https://swapi.co/resource/human/5')),
#  (rdflib.term.URIRef('https://swapi.co/resource/vehicle/30'),
#   rdflib.term.URIRef('https://swapi.co/vocabulary/pilot'),
#   rdflib.term.URIRef('https://swapi.co/resource/human/5')),
#  (rdflib.term.URIRef('https://swapi.co/resource/human/1'),
#   rdflib.term.URIRef('https://swapi.co/vocabulary/film'),
#   rdflib.term.URIRef('https://swapi.co/resource/film/7')),
#  (rdflib.term.URIRef('https://swapi.co/resource/droid/3'),
#   rdflib.term.URIRef('https://swapi.co/vocabulary/film'),
#   rdflib.term.URIRef('https://swapi.co/resource/film/7')),
#  (rdflib.term.URIRef('https://swapi.co/resource/wookiee/13'),
#   rdflib.term.URIRef('https://swapi.co/vocabulary/film'),
#   rdflib.term.URIRef('https://swapi.co/resource/film/7')),
#  (rdflib.term.URIRef('https://swapi.co/vocabulary/Human'),
#   rdflib.term.URIRef('https://swapi.co/vocabulary/film'),
#   rdflib.term.URIRef('https://swapi.co/resource/film/7')),
#  (rdflib.term.URIRef('https://swapi.co/vocabulary/Wookiee'),
#   rdflib.term.URIRef('https://swapi.co/vocabulary/film'),
#   rdflib.term.URIRef('https://swapi.co/resource/film/7')),
#  (rdflib.term.URIRef('https://swapi.co/vocabulary/Droid'),
#   rdflib.term.URIRef('https://swapi.co/vocabulary/film'),
#   rdflib.term.URIRef('https://swapi.co/resource/film/7')),
#  (rdflib.term.URIRef('https://swapi.co/resource/starship/10'),
#   rdflib.term.URIRef('https://swapi.co/vocabulary/film'),
#   rdflib.term.URIRef('https://swapi.co/resource/film/7')),
#  (rdflib.term.URIRef('https://swapi.co/resource/human/84'),
#   rdflib.term.URIRef('https://swapi.co/vocabulary/film'),
#   rdflib.term.URIRef('https://swapi.co/resource/film/7')),
#  (rdflib.term.URIRef('https://swapi.co/resource/droid/87'),
#   rdflib.term.URIRef('https://swapi.co/vocabulary/film'),
#   rdflib.term.URIRef('https://swapi.co/resource/film/7')),
#  (rdflib.term.URIRef('https://swapi.co/resource/human/86'),
#   rdflib.term.URIRef('https://swapi.co/vocabulary/film'),
#   rdflib.term.URIRef('https://swapi.co/resource/film/7')),
#  (rdflib.term.URIRef('https://swapi.co/resource/starship/77'),
#   rdflib.term.URIRef('https://swapi.co/vocabulary/film'),
#   rdflib.term.URIRef('https://swapi.co/resource/film/7')),
#  (rdflib.term.URIRef('https://swapi.co/resource/moncalamari/27'),
#   rdflib.term.URIRef('https://swapi.co/vocabulary/film'),
#   rdflib.term.URIRef('https://swapi.co/resource/film/7')),
#  (rdflib.term.URIRef('https://swapi.co/resource/human/5'),
#   rdflib.term.URIRef('https://swapi.co/vocabulary/film'),
#   rdflib.term.URIRef('https://swapi.co/resource/film/7')),
#  (rdflib.term.URIRef('https://swapi.co/resource/human/85'),
#   rdflib.term.URIRef('https://swapi.co/vocabulary/film'),
#   rdflib.term.URIRef('https://swapi.co/resource/film/7')),
#  (rdflib.term.URIRef('https://swapi.co/resource/human/88'),
#   rdflib.term.URIRef('https://swapi.co/vocabulary/film'),
#   rdflib.term.URIRef('https://swapi.co/resource/film/7')),
#  (rdflib.term.URIRef('https://swapi.co/resource/planet/61'),
#   rdflib.term.URIRef('https://swapi.co/vocabulary/film'),
#   rdflib.term.URIRef('https://swapi.co/resource/film/7')),
#  (rdflib.term.URIRef('https://swapi.co/resource/human/14'),
#   rdflib.term.URIRef('https://swapi.co/vocabulary/film'),
#   rdflib.term.URIRef('https://swapi.co/resource/film/7')),
#  (rdflib.term.URIRef('https://swapi.co/resource/film/7'),
#   rdflib.term.URIRef('https://swapi.co/vocabulary/character'),
#   rdflib.term.URIRef('https://swapi.co/resource/human/88')),
#  (rdflib.term.URIRef('https://swapi.co/resource/planet/28'),
#   rdflib.term.URIRef('https://swapi.co/vocabulary/resident'),
#   rdflib.term.URIRef('https://swapi.co/resource/human/88')),
#  (rdflib.term.URIRef('https://swapi.co/vocabulary/Yodasspecies'),
#   rdflib.term.URIRef('https://swapi.co/vocabulary/planet'),
#   rdflib.term.URIRef('https://swapi.co/resource/planet/28')),
#  (rdflib.term.URIRef('https://swapi.co/resource/droid/23'),
#   rdflib.term.URIRef('https://swapi.co/vocabulary/homeworld'),
#   rdflib.term.URIRef('https://swapi.co/resource/planet/28')),
#  (rdflib.term.URIRef('https://swapi.co/resource/human/84'),
#   rdflib.term.URIRef('https://swapi.co/vocabulary/homeworld'),
#   rdflib.term.URIRef('https://swapi.co/resource/planet/28')),
#  (rdflib.term.URIRef('https://swapi.co/resource/droid/87'),
#   rdflib.term.URIRef('https://swapi.co/vocabulary/homeworld'),
#   rdflib.term.URIRef('https://swapi.co/resource/planet/28')),
#  (rdflib.term.URIRef('https://swapi.co/resource/human/86'),
#   rdflib.term.URIRef('https://swapi.co/vocabulary/homeworld'),
#   rdflib.term.URIRef('https://swapi.co/resource/planet/28')),
#  (rdflib.term.URIRef('https://swapi.co/resource/human/32'),
#   rdflib.term.URIRef('https://swapi.co/vocabulary/homeworld'),
#   rdflib.term.URIRef('https://swapi.co/resource/planet/28')),
#  (rdflib.term.URIRef('https://swapi.co/resource/human/85'),
#   rdflib.term.URIRef('https://swapi.co/vocabulary/homeworld'),
#   rdflib.term.URIRef('https://swapi.co/resource/planet/28')),
#  (rdflib.term.URIRef('https://swapi.co/resource/yodasspecies/20'),
#   rdflib.term.URIRef('https://swapi.co/vocabulary/homeworld'),
#   rdflib.term.URIRef('https://swapi.co/resource/planet/28')),
#  (rdflib.term.URIRef('https://swapi.co/resource/droid/75'),
#   rdflib.term.URIRef('https://swapi.co/vocabulary/homeworld'),
#   rdflib.term.URIRef('https://swapi.co/resource/planet/28')),
#  (rdflib.term.URIRef('https://swapi.co/resource/human/29'),
#   rdflib.term.URIRef('https://swapi.co/vocabulary/homeworld'),
#   rdflib.term.URIRef('https://swapi.co/resource/planet/28')),
#  (rdflib.term.URIRef('https://swapi.co/resource/human/88'),
#   rdflib.term.URIRef('https://swapi.co/vocabulary/homeworld'),
#   rdflib.term.URIRef('https://swapi.co/resource/planet/28')),
#  (rdflib.term.URIRef('https://swapi.co/resource/film/5'),
#   rdflib.term.URIRef('https://swapi.co/vocabulary/character'),
#   rdflib.term.URIRef('https://swapi.co/resource/droid/75')),
#  (rdflib.term.URIRef('https://swapi.co/resource/film/6'),
#   rdflib.term.URIRef('https://swapi.co/vocabulary/character'),
#   rdflib.term.URIRef('https://swapi.co/resource/droid/75')),
#  (rdflib.term.URIRef('https://swapi.co/resource/planet/28'),
#   rdflib.term.URIRef('https://swapi.co/vocabulary/resident'),
#   rdflib.term.URIRef('https://swapi.co/resource/droid/75')),
#  (rdflib.term.URIRef('https://swapi.co/resource/human/11'),
#   rdflib.term.URIRef('https://swapi.co/vocabulary/film'),
#   rdflib.term.URIRef('https://swapi.co/resource/film/6')),
#  (rdflib.term.URIRef('https://swapi.co/resource/human/4'),
#   rdflib.term.URIRef('https://swapi.co/vocabulary/film'),
#   rdflib.term.URIRef('https://swapi.co/resource/film/6')),
#  (rdflib.term.URIRef('https://swapi.co/resource/planet/1'),
#   rdflib.term.URIRef('https://swapi.co/vocabulary/film'),
#   rdflib.term.URIRef('https://swapi.co/resource/film/6')),
#  (rdflib.term.URIRef('https://swapi.co/resource/human/12'),
#   rdflib.term.URIRef('https://swapi.co/vocabulary/film'),
#   rdflib.term.URIRef('https://swapi.co/resource/film/6')),
#  (rdflib.term.URIRef('https://swapi.co/resource/vehicle/71'),
#   rdflib.term.URIRef('https://swapi.co/vocabulary/film'),
#   rdflib.term.URIRef('https://swapi.co/resource/film/6')),
#  (rdflib.term.URIRef('https://swapi.co/resource/planet/9'),
#   rdflib.term.URIRef('https://swapi.co/vocabulary/film'),
#   rdflib.term.URIRef('https://swapi.co/resource/film/6')),
#  (rdflib.term.URIRef('https://swapi.co/resource/vehicle/76'),
#   rdflib.term.URIRef('https://swapi.co/vocabulary/film'),
#   rdflib.term.URIRef('https://swapi.co/resource/film/6')),
#  (rdflib.term.URIRef('https://swapi.co/resource/vehicle/72'),
#   rdflib.term.URIRef('https://swapi.co/vocabulary/film'),
#   rdflib.term.URIRef('https://swapi.co/resource/film/6')),
#  (rdflib.term.URIRef('https://swapi.co/resource/human/1'),
#   rdflib.term.URIRef('https://swapi.co/vocabulary/film'),
#   rdflib.term.URIRef('https://swapi.co/resource/film/6')),
#  (rdflib.term.URIRef('https://swapi.co/vocabulary/Cerean'),
#   rdflib.term.URIRef('https://swapi.co/vocabulary/film'),
#   rdflib.term.URIRef('https://swapi.co/resource/film/6')),
#  (rdflib.term.URIRef('https://swapi.co/resource/droid/3'),
#   rdflib.term.URIRef('https://swapi.co/vocabulary/film'),
#   rdflib.term.URIRef('https://swapi.co/resource/film/6')),
#  (rdflib.term.URIRef('https://swapi.co/resource/planet/8'),
#   rdflib.term.URIRef('https://swapi.co/vocabulary/film'),
#   rdflib.term.URIRef('https://swapi.co/resource/film/6')),
#  (rdflib.term.URIRef('https://swapi.co/resource/nautolan/53'),
#   rdflib.term.URIRef('https://swapi.co/vocabulary/film'),
#   rdflib.term.URIRef('https://swapi.co/resource/film/6')),
#  (rdflib.term.URIRef('https://swapi.co/resource/zabrak/54'),
#   rdflib.term.URIRef('https://swapi.co/vocabulary/film'),
#   rdflib.term.URIRef('https://swapi.co/resource/film/6')),
#  (rdflib.term.URIRef('https://swapi.co/vocabulary/Yodasspecies'),
#   rdflib.term.URIRef('https://swapi.co/vocabulary/film'),
#   rdflib.term.URIRef('https://swapi.co/resource/film/6')),
#  (rdflib.term.URIRef('https://swapi.co/resource/starship/66'),
#   rdflib.term.URIRef('https://swapi.co/vocabulary/film'),
#   rdflib.term.URIRef('https://swapi.co/resource/film/6')),
#  (rdflib.term.URIRef('https://swapi.co/resource/human/35'),
#   rdflib.term.URIRef('https://swapi.co/vocabulary/film'),
#   rdflib.term.URIRef('https://swapi.co/resource/film/6')),
#  (rdflib.term.URIRef('https://swapi.co/resource/starship/64'),
#   rdflib.term.URIRef('https://swapi.co/vocabulary/film'),
#   rdflib.term.URIRef('https://swapi.co/resource/film/6')),
#  (rdflib.term.URIRef('https://swapi.co/resource/starship/74'),
#   rdflib.term.URIRef('https://swapi.co/vocabulary/film'),
#   rdflib.term.URIRef('https://swapi.co/resource/film/6')),
#  (rdflib.term.URIRef('https://swapi.co/resource/twilek/46'),
#   rdflib.term.URIRef('https://swapi.co/vocabulary/film'),
#   rdflib.term.URIRef('https://swapi.co/resource/film/6')),
#  (rdflib.term.URIRef('https://swapi.co/resource/wookiee/13'),
#   rdflib.term.URIRef('https://swapi.co/vocabulary/film'),
#   rdflib.term.URIRef('https://swapi.co/resource/film/6')),
#  (rdflib.term.URIRef('https://swapi.co/resource/starship/63'),
#   rdflib.term.URIRef('https://swapi.co/vocabulary/film'),
#   rdflib.term.URIRef('https://swapi.co/resource/film/6')),
#  (rdflib.term.URIRef('https://swapi.co/vocabulary/Human'),
#   rdflib.term.URIRef('https://swapi.co/vocabulary/film'),
#   rdflib.term.URIRef('https://swapi.co/resource/film/6')),
#  (rdflib.term.URIRef('https://swapi.co/vocabulary/Skakoan'),
#   rdflib.term.URIRef('https://swapi.co/vocabulary/film'),
#   rdflib.term.URIRef('https://swapi.co/resource/film/6')),
#  (rdflib.term.URIRef('https://swapi.co/vocabulary/Wookiee'),
#   rdflib.term.URIRef('https://swapi.co/vocabulary/film'),
#   rdflib.term.URIRef('https://swapi.co/resource/film/6')),
#  (rdflib.term.URIRef('https://swapi.co/resource/planet/14'),
#   rdflib.term.URIRef('https://swapi.co/vocabulary/film'),
#   rdflib.term.URIRef('https://swapi.co/resource/film/6')),
#  (rdflib.term.URIRef('https://swapi.co/resource/wookiee/80'),
#   rdflib.term.URIRef('https://swapi.co/vocabulary/film'),
#   rdflib.term.URIRef('https://swapi.co/resource/film/6')),
#  (rdflib.term.URIRef('https://swapi.co/resource/starship/61'),
#   rdflib.term.URIRef('https://swapi.co/vocabulary/film'),
#   rdflib.term.URIRef('https://swapi.co/resource/film/6')),
#  (rdflib.term.URIRef('https://swapi.co/resource/planet/15'),
#   rdflib.term.URIRef('https://swapi.co/vocabulary/film'),
#   rdflib.term.URIRef('https://swapi.co/resource/film/6')),
#  (rdflib.term.URIRef('https://swapi.co/resource/planet/2'),
#   rdflib.term.URIRef('https://swapi.co/vocabulary/film'),
#   rdflib.term.URIRef('https://swapi.co/resource/film/6')),
#  (rdflib.term.URIRef('https://swapi.co/resource/starship/2'),
#   rdflib.term.URIRef('https://swapi.co/vocabulary/film'),
#   rdflib.term.URIRef('https://swapi.co/resource/film/6')),
#  (rdflib.term.URIRef('https://swapi.co/resource/droid/2'),
#   rdflib.term.URIRef('https://swapi.co/vocabulary/film'),
#   rdflib.term.URIRef('https://swapi.co/resource/film/6')),
#  (rdflib.term.URIRef('https://swapi.co/vocabulary/Droid'),
#   rdflib.term.URIRef('https://swapi.co/vocabulary/film'),
#   rdflib.term.URIRef('https://swapi.co/resource/film/6')),
#  (rdflib.term.URIRef('https://swapi.co/vocabulary/Twilek'),
#   rdflib.term.URIRef('https://swapi.co/vocabulary/film'),
#   rdflib.term.URIRef('https://swapi.co/resource/film/6')),
#  (rdflib.term.URIRef('https://swapi.co/resource/planet/18'),
#   rdflib.term.URIRef('https://swapi.co/vocabulary/film'),
#   rdflib.term.URIRef('https://swapi.co/resource/film/6')),
#  (rdflib.term.URIRef('https://swapi.co/vocabulary/Pauan'),
#   rdflib.term.URIRef('https://swapi.co/vocabulary/film'),
#   rdflib.term.URIRef('https://swapi.co/resource/film/6')),
#  (rdflib.term.URIRef('https://swapi.co/resource/pauan/83'),
#   rdflib.term.URIRef('https://swapi.co/vocabulary/film'),
#   rdflib.term.URIRef('https://swapi.co/resource/film/6')),
#  (rdflib.term.URIRef('https://swapi.co/resource/keldor/58'),
#   rdflib.term.URIRef('https://swapi.co/vocabulary/film'),
#   rdflib.term.URIRef('https://swapi.co/resource/film/6')),
#  (rdflib.term.URIRef('https://swapi.co/resource/iktotchi/56'),
#   rdflib.term.URIRef('https://swapi.co/vocabulary/film'),
#   rdflib.term.URIRef('https://swapi.co/resource/film/6')),
#  (rdflib.term.URIRef('https://swapi.co/vocabulary/Keldor'),
#   rdflib.term.URIRef('https://swapi.co/vocabulary/film'),
#   rdflib.term.URIRef('https://swapi.co/resource/film/6')),
#  (rdflib.term.URIRef('https://swapi.co/vocabulary/Clawdite'),
#   rdflib.term.URIRef('https://swapi.co/vocabulary/film'),
#   rdflib.term.URIRef('https://swapi.co/resource/film/6')),
#  (rdflib.term.URIRef('https://swapi.co/resource/cerean/52'),
#   rdflib.term.URIRef('https://swapi.co/vocabulary/film'),
#   rdflib.term.URIRef('https://swapi.co/resource/film/6')),
#  (rdflib.term.URIRef('https://swapi.co/resource/togruta/78'),
#   rdflib.term.URIRef('https://swapi.co/vocabulary/film'),
#   rdflib.term.URIRef('https://swapi.co/resource/film/6')),
#  (rdflib.term.URIRef('https://swapi.co/vocabulary/Togruta'),
#   rdflib.term.URIRef('https://swapi.co/vocabulary/film'),
#   rdflib.term.URIRef('https://swapi.co/resource/film/6')),
#  (rdflib.term.URIRef('https://swapi.co/resource/umbaran/82'),
#   rdflib.term.URIRef('https://swapi.co/vocabulary/film'),
#   rdflib.term.URIRef('https://swapi.co/resource/film/6')),
#  (rdflib.term.URIRef('https://swapi.co/resource/mirialan/64'),
#   rdflib.term.URIRef('https://swapi.co/vocabulary/film'),
#   rdflib.term.URIRef('https://swapi.co/resource/film/6')),
#  (rdflib.term.URIRef('https://swapi.co/resource/tholothian/55'),
#   rdflib.term.URIRef('https://swapi.co/vocabulary/film'),
#   rdflib.term.URIRef('https://swapi.co/resource/film/6')),
#  (rdflib.term.URIRef('https://swapi.co/resource/human/81'),
#   rdflib.term.URIRef('https://swapi.co/vocabulary/film'),
#   rdflib.term.URIRef('https://swapi.co/resource/film/6')),
#  (rdflib.term.URIRef('https://swapi.co/resource/human/11'),
#   rdflib.term.URIRef('https://swapi.co/vocabulary/film'),
#   rdflib.term.URIRef('https://swapi.co/resource/film/6')),
#  (rdflib.term.URIRef('https://swapi.co/resource/human/51'),
#   rdflib.term.URIRef('https://swapi.co/vocabulary/film'),
#   rdflib.term.URIRef('https://swapi.co/resource/film/6')),
#  (rdflib.term.URIRef('https://swapi.co/vocabulary/Toong'),
#   rdflib.term.URIRef('https://swapi.co/vocabulary/film'),
#   rdflib.term.URIRef('https://swapi.co/resource/film/6')),
#  (rdflib.term.URIRef('https://swapi.co/resource/geonosian/63'),
#   rdflib.term.URIRef('https://swapi.co/vocabulary/film'),
#   rdflib.term.URIRef('https://swapi.co/resource/film/6')),
#  (rdflib.term.URIRef('https://swapi.co/vocabulary/Geonosian'),
#   rdflib.term.URIRef('https://swapi.co/vocabulary/film'),
#   rdflib.term.URIRef('https://swapi.co/resource/film/6')),
#  (rdflib.term.URIRef('https://swapi.co/resource/vehicle/50'),
#   rdflib.term.URIRef('https://swapi.co/vocabulary/film'),
#   rdflib.term.URIRef('https://swapi.co/resource/film/6')),
#  (rdflib.term.URIRef('https://swapi.co/resource/vehicle/60'),
#   rdflib.term.URIRef('https://swapi.co/vocabulary/film'),
#   rdflib.term.URIRef('https://swapi.co/resource/film/6')),
#  (rdflib.term.URIRef('https://swapi.co/resource/vehicle/33'),
#   rdflib.term.URIRef('https://swapi.co/vocabulary/film'),
#   rdflib.term.URIRef('https://swapi.co/resource/film/6')),
#  (rdflib.term.URIRef('https://swapi.co/resource/vehicle/67'),
#   rdflib.term.URIRef('https://swapi.co/vocabulary/film'),
#   rdflib.term.URIRef('https://swapi.co/resource/film/6')),
#  (rdflib.term.URIRef('https://swapi.co/resource/starship/59'),
#   rdflib.term.URIRef('https://swapi.co/vocabulary/film'),
#   rdflib.term.URIRef('https://swapi.co/resource/film/6')),
#  (rdflib.term.URIRef('https://swapi.co/resource/starship/75'),
#   rdflib.term.URIRef('https://swapi.co/vocabulary/film'),
#   rdflib.term.URIRef('https://swapi.co/resource/film/6')),
#  (rdflib.term.URIRef('https://swapi.co/resource/starship/48'),
#   rdflib.term.URIRef('https://swapi.co/vocabulary/film'),
#   rdflib.term.URIRef('https://swapi.co/resource/film/6')),
#  (rdflib.term.URIRef('https://swapi.co/resource/human/10'),
#   rdflib.term.URIRef('https://swapi.co/vocabulary/film'),
#   rdflib.term.URIRef('https://swapi.co/resource/film/6')),
#  (rdflib.term.URIRef('https://swapi.co/vocabulary/Chagrian'),
#   rdflib.term.URIRef('https://swapi.co/vocabulary/film'),
#   rdflib.term.URIRef('https://swapi.co/resource/film/6')),
#  (rdflib.term.URIRef('https://swapi.co/vocabulary/Muun'),
#   rdflib.term.URIRef('https://swapi.co/vocabulary/film'),
#   rdflib.term.URIRef('https://swapi.co/resource/film/6')),
#  (rdflib.term.URIRef('https://swapi.co/resource/human/5'),
#   rdflib.term.URIRef('https://swapi.co/vocabulary/film'),
#   rdflib.term.URIRef('https://swapi.co/resource/film/6')),
#  (rdflib.term.URIRef('https://swapi.co/vocabulary/Kaleesh'),
#   rdflib.term.URIRef('https://swapi.co/vocabulary/film'),
#   rdflib.term.URIRef('https://swapi.co/resource/film/6')),
#  (rdflib.term.URIRef('https://swapi.co/resource/kaleesh/79'),
#   rdflib.term.URIRef('https://swapi.co/vocabulary/film'),
#   rdflib.term.URIRef('https://swapi.co/resource/film/6')),
#  (rdflib.term.URIRef('https://swapi.co/resource/starship/32'),
#   rdflib.term.URIRef('https://swapi.co/vocabulary/film'),
#   rdflib.term.URIRef('https://swapi.co/resource/film/6')),
#  (rdflib.term.URIRef('https://swapi.co/resource/planet/16'),
#   rdflib.term.URIRef('https://swapi.co/vocabulary/film'),
#   rdflib.term.URIRef('https://swapi.co/resource/film/6')),
#  (rdflib.term.URIRef('https://swapi.co/resource/planet/17'),
#   rdflib.term.URIRef('https://swapi.co/vocabulary/film'),
#   rdflib.term.URIRef('https://swapi.co/resource/film/6')),
#  (rdflib.term.URIRef('https://swapi.co/resource/vehicle/56'),
#   rdflib.term.URIRef('https://swapi.co/vocabulary/film'),
#   rdflib.term.URIRef('https://swapi.co/resource/film/6')),
#  (rdflib.term.URIRef('https://swapi.co/resource/vehicle/70'),
#   rdflib.term.URIRef('https://swapi.co/vocabulary/film'),
#   rdflib.term.URIRef('https://swapi.co/resource/film/6')),
#  (rdflib.term.URIRef('https://swapi.co/resource/vehicle/69'),
#   rdflib.term.URIRef('https://swapi.co/vocabulary/film'),
#   rdflib.term.URIRef('https://swapi.co/resource/film/6')),
#  (rdflib.term.URIRef('https://swapi.co/resource/starship/65'),
#   rdflib.term.URIRef('https://swapi.co/vocabulary/film'),
#   rdflib.term.URIRef('https://swapi.co/resource/film/6')),
#  (rdflib.term.URIRef('https://swapi.co/resource/vehicle/62'),
#   rdflib.term.URIRef('https://swapi.co/vocabulary/film'),
#   rdflib.term.URIRef('https://swapi.co/resource/film/6')),
#  (rdflib.term.URIRef('https://swapi.co/resource/vehicle/73'),
#   rdflib.term.URIRef('https://swapi.co/vocabulary/film'),
#   rdflib.term.URIRef('https://swapi.co/resource/film/6')),
#  (rdflib.term.URIRef('https://swapi.co/resource/planet/5'),
#   rdflib.term.URIRef('https://swapi.co/vocabulary/film'),
#   rdflib.term.URIRef('https://swapi.co/resource/film/6')),
#  (rdflib.term.URIRef('https://swapi.co/resource/human/68'),
#   rdflib.term.URIRef('https://swapi.co/vocabulary/film'),
#   rdflib.term.URIRef('https://swapi.co/resource/film/6')),
#  (rdflib.term.URIRef('https://swapi.co/resource/neimodian/33'),
#   rdflib.term.URIRef('https://swapi.co/vocabulary/film'),
#   rdflib.term.URIRef('https://swapi.co/resource/film/6')),
#  (rdflib.term.URIRef('https://swapi.co/resource/planet/12'),
#   rdflib.term.URIRef('https://swapi.co/vocabulary/film'),
#   rdflib.term.URIRef('https://swapi.co/resource/film/6')),
#  (rdflib.term.URIRef('https://swapi.co/resource/human/67'),
#   rdflib.term.URIRef('https://swapi.co/vocabulary/film'),
#   rdflib.term.URIRef('https://swapi.co/resource/film/6')),
#  (rdflib.term.URIRef('https://swapi.co/resource/planet/13'),
#   rdflib.term.URIRef('https://swapi.co/vocabulary/film'),
#   rdflib.term.URIRef('https://swapi.co/resource/film/6')),
#  (rdflib.term.URIRef('https://swapi.co/resource/planet/19'),
#   rdflib.term.URIRef('https://swapi.co/vocabulary/film'),
#   rdflib.term.URIRef('https://swapi.co/resource/film/6')),
#  (rdflib.term.URIRef('https://swapi.co/resource/vehicle/53'),
#   rdflib.term.URIRef('https://swapi.co/vocabulary/film'),
#   rdflib.term.URIRef('https://swapi.co/resource/film/6')),
#  (rdflib.term.URIRef('https://swapi.co/resource/starship/68'),
#   rdflib.term.URIRef('https://swapi.co/vocabulary/film'),
#   rdflib.term.URIRef('https://swapi.co/resource/film/6')),
#  (rdflib.term.URIRef('https://swapi.co/resource/human/21'),
#   rdflib.term.URIRef('https://swapi.co/vocabulary/film'),
#   rdflib.term.URIRef('https://swapi.co/resource/film/6')),
#  (rdflib.term.URIRef('https://swapi.co/resource/human/7'),
#   rdflib.term.URIRef('https://swapi.co/vocabulary/film'),
#   rdflib.term.URIRef('https://swapi.co/resource/film/6')),
#  (rdflib.term.URIRef('https://swapi.co/resource/human/6'),
#   rdflib.term.URIRef('https://swapi.co/vocabulary/film'),
#   rdflib.term.URIRef('https://swapi.co/resource/film/6')),
#  (rdflib.term.URIRef('https://swapi.co/resource/yodasspecies/20'),
#   rdflib.term.URIRef('https://swapi.co/vocabulary/film'),
#   rdflib.term.URIRef('https://swapi.co/resource/film/6')),
#  (rdflib.term.URIRef('https://swapi.co/resource/droid/75'),
#   rdflib.term.URIRef('https://swapi.co/vocabulary/film'),
#   rdflib.term.URIRef('https://swapi.co/resource/film/6')),
#  (rdflib.term.URIRef('https://swapi.co/vocabulary/Tholothian'),
#   rdflib.term.URIRef('https://swapi.co/vocabulary/film'),
#   rdflib.term.URIRef('https://swapi.co/resource/film/6')),
#  (rdflib.term.URIRef('https://swapi.co/vocabulary/Mirialan'),
#   rdflib.term.URIRef('https://swapi.co/vocabulary/film'),
#   rdflib.term.URIRef('https://swapi.co/resource/film/6')),
#  (rdflib.term.URIRef('https://swapi.co/vocabulary/Quermian'),
#   rdflib.term.URIRef('https://swapi.co/vocabulary/film'),
#   rdflib.term.URIRef('https://swapi.co/resource/film/6')),
#  (rdflib.term.URIRef('https://swapi.co/vocabulary/Iktotchi'),
#   rdflib.term.URIRef('https://swapi.co/vocabulary/film'),
#   rdflib.term.URIRef('https://swapi.co/resource/film/6')),
#  (rdflib.term.URIRef('https://swapi.co/resource/film/5'),
#   rdflib.term.URIRef('https://swapi.co/vocabulary/starship'),
#   rdflib.term.URIRef('https://swapi.co/resource/starship/32')),
#  (rdflib.term.URIRef('https://swapi.co/resource/film/6'),
#   rdflib.term.URIRef('https://swapi.co/vocabulary/starship'),
#   rdflib.term.URIRef('https://swapi.co/resource/starship/32')),
#  (rdflib.term.URIRef('https://swapi.co/resource/film/4'),
#   rdflib.term.URIRef('https://swapi.co/vocabulary/starship'),
#   rdflib.term.URIRef('https://swapi.co/resource/starship/32')),
#  (rdflib.term.URIRef('https://swapi.co/resource/human/11'),
#   rdflib.term.URIRef('https://swapi.co/vocabulary/film'),
#   rdflib.term.URIRef('https://swapi.co/resource/film/4')),
#  (rdflib.term.URIRef('https://swapi.co/resource/planet/1'),
#   rdflib.term.URIRef('https://swapi.co/vocabulary/film'),
#   rdflib.term.URIRef('https://swapi.co/resource/film/4')),
#  (rdflib.term.URIRef('https://swapi.co/resource/chagrian/59'),
#   rdflib.term.URIRef('https://swapi.co/vocabulary/film'),
#   rdflib.term.URIRef('https://swapi.co/resource/film/4')),
#  (rdflib.term.URIRef('https://swapi.co/resource/human/39'),
#   rdflib.term.URIRef('https://swapi.co/vocabulary/film'),
#   rdflib.term.URIRef('https://swapi.co/resource/film/4')),
#  (rdflib.term.URIRef('https://swapi.co/resource/planet/9'),
#   rdflib.term.URIRef('https://swapi.co/vocabulary/film'),
# ...
#   rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'),
#   rdflib.term.URIRef('https://swapi.co/vocabulary/Species')),
#  (rdflib.term.URIRef('https://swapi.co/vocabulary/Umbaran'),
#   rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'),
#   rdflib.term.URIRef('https://swapi.co/vocabulary/Species')),
#  (rdflib.term.URIRef('https://swapi.co/vocabulary/Toong'),
#   rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'),
#   rdflib.term.URIRef('https://swapi.co/vocabulary/Species')),
#  (rdflib.term.URIRef('https://swapi.co/vocabulary/Geonosian'),
#   rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'),
#   rdflib.term.URIRef('https://swapi.co/vocabulary/Species')),
#  (rdflib.term.URIRef('https://swapi.co/vocabulary/Chagrian'),
#   rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'),
#   rdflib.term.URIRef('https://swapi.co/vocabulary/Species')),
#  (rdflib.term.URIRef('https://swapi.co/vocabulary/Muun'),
#   rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'),
#   rdflib.term.URIRef('https://swapi.co/vocabulary/Species')),
#  (rdflib.term.URIRef('https://swapi.co/vocabulary/Moncalamari'),
#   rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'),
#   rdflib.term.URIRef('https://swapi.co/vocabulary/Species')),
#  (rdflib.term.URIRef('https://swapi.co/vocabulary/Kaminoan'),
#   rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'),
#   rdflib.term.URIRef('https://swapi.co/vocabulary/Species')),
#  (rdflib.term.URIRef('https://swapi.co/vocabulary/Kaleesh'),
#   rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'),
#   rdflib.term.URIRef('https://swapi.co/vocabulary/Species')),
#  (rdflib.term.URIRef('https://swapi.co/vocabulary/Aleena'),
#   rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'),
#   rdflib.term.URIRef('https://swapi.co/vocabulary/Species')),
#  (rdflib.term.URIRef('https://swapi.co/vocabulary/Trandoshan'),
#   rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'),
#   rdflib.term.URIRef('https://swapi.co/vocabulary/Species')),
#  (rdflib.term.URIRef('https://swapi.co/vocabulary/Tholothian'),
#   rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'),
#   rdflib.term.URIRef('https://swapi.co/vocabulary/Species')),
#  (rdflib.term.URIRef('https://swapi.co/vocabulary/Mirialan'),
#   rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'),
#   rdflib.term.URIRef('https://swapi.co/vocabulary/Species')),
#  (rdflib.term.URIRef('https://swapi.co/vocabulary/Quermian'),
#   rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'),
#   rdflib.term.URIRef('https://swapi.co/vocabulary/Species')),
#  (rdflib.term.URIRef('https://swapi.co/vocabulary/Iktotchi'),
#   rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'),
#   rdflib.term.URIRef('https://swapi.co/vocabulary/Species')),
#  (rdflib.term.URIRef('https://swapi.co/resource/hutt/16'),
#   rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'),
#   rdflib.term.URIRef('https://swapi.co/vocabulary/Hutt')),
#  (rdflib.term.URIRef('https://swapi.co/resource/film/1'),
#   rdflib.term.URIRef('https://swapi.co/vocabulary/character'),
#   rdflib.term.URIRef('https://swapi.co/resource/hutt/16')),
#  (rdflib.term.URIRef('https://swapi.co/resource/film/3'),
#   rdflib.term.URIRef('https://swapi.co/vocabulary/character'),
#   rdflib.term.URIRef('https://swapi.co/resource/hutt/16')),
#  (rdflib.term.URIRef('https://swapi.co/resource/film/4'),
#   rdflib.term.URIRef('https://swapi.co/vocabulary/character'),
#   rdflib.term.URIRef('https://swapi.co/resource/hutt/16')),
#  (rdflib.term.URIRef('https://swapi.co/vocabulary/Hutt'),
#   rdflib.term.URIRef('https://swapi.co/vocabulary/character'),
#   rdflib.term.URIRef('https://swapi.co/resource/hutt/16')),
#  (rdflib.term.URIRef('https://swapi.co/resource/planet/24'),
#   rdflib.term.URIRef('https://swapi.co/vocabulary/resident'),
#   rdflib.term.URIRef('https://swapi.co/resource/hutt/16')),
#  (rdflib.term.URIRef('https://swapi.co/resource/human/4'),
#   rdflib.term.URIRef('https://swapi.co/vocabulary/film'),
#   rdflib.term.URIRef('https://swapi.co/resource/film/1')),
#  (rdflib.term.URIRef('https://swapi.co/resource/planet/1'),
#   rdflib.term.URIRef('https://swapi.co/vocabulary/film'),
#   rdflib.term.URIRef('https://swapi.co/resource/film/1')),
#  (rdflib.term.URIRef('https://swapi.co/resource/vehicle/6'),
#   rdflib.term.URIRef('https://swapi.co/vocabulary/film'),
#   rdflib.term.URIRef('https://swapi.co/resource/film/1')),
#  (rdflib.term.URIRef('https://swapi.co/resource/human/12'),
#   rdflib.term.URIRef('https://swapi.co/vocabulary/film'),
#   rdflib.term.URIRef('https://swapi.co/resource/film/1')),
#  (rdflib.term.URIRef('https://swapi.co/resource/starship/11'),
#   rdflib.term.URIRef('https://swapi.co/vocabulary/film'),
#   rdflib.term.URIRef('https://swapi.co/resource/film/1')),
#  (rdflib.term.URIRef('https://swapi.co/resource/human/1'),
#   rdflib.term.URIRef('https://swapi.co/vocabulary/film'),
#   rdflib.term.URIRef('https://swapi.co/resource/film/1')),
#  (rdflib.term.URIRef('https://swapi.co/resource/droid/3'),
#   rdflib.term.URIRef('https://swapi.co/vocabulary/film'),
#   rdflib.term.URIRef('https://swapi.co/resource/film/1')),
#  (rdflib.term.URIRef('https://swapi.co/vocabulary/Hutt'),
#   rdflib.term.URIRef('https://swapi.co/vocabulary/film'),
#   rdflib.term.URIRef('https://swapi.co/resource/film/1')),
#  (rdflib.term.URIRef('https://swapi.co/resource/hutt/16'),
#   rdflib.term.URIRef('https://swapi.co/vocabulary/film'),
#   rdflib.term.URIRef('https://swapi.co/resource/film/1')),
#  (rdflib.term.URIRef('https://swapi.co/resource/human/19'),
#   rdflib.term.URIRef('https://swapi.co/vocabulary/film'),
#   rdflib.term.URIRef('https://swapi.co/resource/film/1')),
#  (rdflib.term.URIRef('https://swapi.co/resource/starship/12'),
#   rdflib.term.URIRef('https://swapi.co/vocabulary/film'),
#   rdflib.term.URIRef('https://swapi.co/resource/film/1')),
#  (rdflib.term.URIRef('https://swapi.co/resource/starship/13'),
#   rdflib.term.URIRef('https://swapi.co/vocabulary/film'),
#   rdflib.term.URIRef('https://swapi.co/resource/film/1')),
#  (rdflib.term.URIRef('https://swapi.co/resource/starship/5'),
#   rdflib.term.URIRef('https://swapi.co/vocabulary/film'),
#   rdflib.term.URIRef('https://swapi.co/resource/film/1')),
#  (rdflib.term.URIRef('https://swapi.co/resource/human/18'),
#   rdflib.term.URIRef('https://swapi.co/vocabulary/film'),
#   rdflib.term.URIRef('https://swapi.co/resource/film/1')),
#  (rdflib.term.URIRef('https://swapi.co/resource/wookiee/13'),
#   rdflib.term.URIRef('https://swapi.co/vocabulary/film'),
#   rdflib.term.URIRef('https://swapi.co/resource/film/1')),
#  (rdflib.term.URIRef('https://swapi.co/vocabulary/Human'),
#   rdflib.term.URIRef('https://swapi.co/vocabulary/film'),
#   rdflib.term.URIRef('https://swapi.co/resource/film/1')),
#  (rdflib.term.URIRef('https://swapi.co/vocabulary/Wookiee'),
#   rdflib.term.URIRef('https://swapi.co/vocabulary/film'),
#   rdflib.term.URIRef('https://swapi.co/resource/film/1')),
#  (rdflib.term.URIRef('https://swapi.co/resource/starship/3'),
#   rdflib.term.URIRef('https://swapi.co/vocabulary/film'),
#   rdflib.term.URIRef('https://swapi.co/resource/film/1')),
#  (rdflib.term.URIRef('https://swapi.co/resource/planet/2'),
#   rdflib.term.URIRef('https://swapi.co/vocabulary/film'),
#   rdflib.term.URIRef('https://swapi.co/resource/film/1')),
#  (rdflib.term.URIRef('https://swapi.co/resource/starship/2'),
#   rdflib.term.URIRef('https://swapi.co/vocabulary/film'),
#   rdflib.term.URIRef('https://swapi.co/resource/film/1')),
#  (rdflib.term.URIRef('https://swapi.co/resource/droid/2'),
#   rdflib.term.URIRef('https://swapi.co/vocabulary/film'),
#   rdflib.term.URIRef('https://swapi.co/resource/film/1')),
#  (rdflib.term.URIRef('https://swapi.co/vocabulary/Droid'),
#   rdflib.term.URIRef('https://swapi.co/vocabulary/film'),
#   rdflib.term.URIRef('https://swapi.co/resource/film/1')),
#  (rdflib.term.URIRef('https://swapi.co/resource/starship/10'),
#   rdflib.term.URIRef('https://swapi.co/vocabulary/film'),
#   rdflib.term.URIRef('https://swapi.co/resource/film/1')),
#  (rdflib.term.URIRef('https://swapi.co/vocabulary/Rodian'),
#   rdflib.term.URIRef('https://swapi.co/vocabulary/film'),
#   rdflib.term.URIRef('https://swapi.co/resource/film/1')),
#  (rdflib.term.URIRef('https://swapi.co/resource/rodian/15'),
#   rdflib.term.URIRef('https://swapi.co/vocabulary/film'),
#   rdflib.term.URIRef('https://swapi.co/resource/film/1')),
#  (rdflib.term.URIRef('https://swapi.co/vocabulary/Umbaran'),
#   rdflib.term.URIRef('https://swapi.co/vocabulary/film'),
#   rdflib.term.URIRef('https://swapi.co/resource/film/1')),
#  (rdflib.term.URIRef('https://swapi.co/resource/human/81'),
#   rdflib.term.URIRef('https://swapi.co/vocabulary/film'),
#   rdflib.term.URIRef('https://swapi.co/resource/film/1')),
#  (rdflib.term.URIRef('https://swapi.co/resource/human/9'),
#   rdflib.term.URIRef('https://swapi.co/vocabulary/film'),
#   rdflib.term.URIRef('https://swapi.co/resource/film/1')),
#  (rdflib.term.URIRef('https://swapi.co/resource/vehicle/4'),
#   rdflib.term.URIRef('https://swapi.co/vocabulary/film'),
#   rdflib.term.URIRef('https://swapi.co/resource/film/1')),
#  (rdflib.term.URIRef('https://swapi.co/resource/vehicle/7'),
#   rdflib.term.URIRef('https://swapi.co/vocabulary/film'),
#   rdflib.term.URIRef('https://swapi.co/resource/film/1')),
#  (rdflib.term.URIRef('https://swapi.co/resource/vehicle/8'),
#   rdflib.term.URIRef('https://swapi.co/vocabulary/film'),
#   rdflib.term.URIRef('https://swapi.co/resource/film/1')),
#  (rdflib.term.URIRef('https://swapi.co/resource/human/10'),
#   rdflib.term.URIRef('https://swapi.co/vocabulary/film'),
#   rdflib.term.URIRef('https://swapi.co/resource/film/1')),
#  (rdflib.term.URIRef('https://swapi.co/resource/human/5'),
#   rdflib.term.URIRef('https://swapi.co/vocabulary/film'),
#   rdflib.term.URIRef('https://swapi.co/resource/film/1')),
#  (rdflib.term.URIRef('https://swapi.co/resource/planet/3'),
#   rdflib.term.URIRef('https://swapi.co/vocabulary/film'),
#   rdflib.term.URIRef('https://swapi.co/resource/film/1')),
#  (rdflib.term.URIRef('https://swapi.co/resource/starship/9'),
#   rdflib.term.URIRef('https://swapi.co/vocabulary/film'),
#   rdflib.term.URIRef('https://swapi.co/resource/film/1')),
#  (rdflib.term.URIRef('https://swapi.co/resource/human/7'),
#   rdflib.term.URIRef('https://swapi.co/vocabulary/film'),
#   rdflib.term.URIRef('https://swapi.co/resource/film/1')),
#  (rdflib.term.URIRef('https://swapi.co/resource/human/6'),
#   rdflib.term.URIRef('https://swapi.co/vocabulary/film'),
#   rdflib.term.URIRef('https://swapi.co/resource/film/1')),
#  (rdflib.term.URIRef('https://swapi.co/resource/human/14'),
#   rdflib.term.URIRef('https://swapi.co/vocabulary/film'),
#   rdflib.term.URIRef('https://swapi.co/resource/film/1')),
#  (rdflib.term.URIRef('https://swapi.co/resource/droid/8'),
#   rdflib.term.URIRef('https://swapi.co/vocabulary/film'),
#   rdflib.term.URIRef('https://swapi.co/resource/film/1')),
#  (rdflib.term.URIRef('https://swapi.co/resource/film/1'),
#   rdflib.term.URIRef('https://swapi.co/vocabulary/vehicle'),
#   rdflib.term.URIRef('https://swapi.co/resource/vehicle/4')),
#  (rdflib.term.URIRef('https://swapi.co/resource/film/5'),
#   rdflib.term.URIRef('https://swapi.co/vocabulary/vehicle'),
#   rdflib.term.URIRef('https://swapi.co/resource/vehicle/4')),
#  (rdflib.term.URIRef('https://swapi.co/resource/vehicle/6'),
#   rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'),
#   rdflib.term.URIRef('https://swapi.co/vocabulary/Vehicle')),
#  (rdflib.term.URIRef('https://swapi.co/resource/vehicle/24'),
#   rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'),
#   rdflib.term.URIRef('https://swapi.co/vocabulary/Vehicle')),
#  (rdflib.term.URIRef('https://swapi.co/resource/vehicle/54'),
#   rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'),
#   rdflib.term.URIRef('https://swapi.co/vocabulary/Vehicle')),
#  (rdflib.term.URIRef('https://swapi.co/resource/vehicle/71'),
#   rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'),
#   rdflib.term.URIRef('https://swapi.co/vocabulary/Vehicle')),
#  (rdflib.term.URIRef('https://swapi.co/resource/vehicle/18'),
#   rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'),
#   rdflib.term.URIRef('https://swapi.co/vocabulary/Vehicle')),
#  (rdflib.term.URIRef('https://swapi.co/resource/vehicle/76'),
#   rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'),
#   rdflib.term.URIRef('https://swapi.co/vocabulary/Vehicle')),
#  (rdflib.term.URIRef('https://swapi.co/resource/vehicle/25'),
#   rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'),
#   rdflib.term.URIRef('https://swapi.co/vocabulary/Vehicle')),
#  (rdflib.term.URIRef('https://swapi.co/resource/vehicle/55'),
#   rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'),
#   rdflib.term.URIRef('https://swapi.co/vocabulary/Vehicle')),
#  (rdflib.term.URIRef('https://swapi.co/resource/vehicle/42'),
#   rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'),
#   rdflib.term.URIRef('https://swapi.co/vocabulary/Vehicle')),
#  (rdflib.term.URIRef('https://swapi.co/resource/vehicle/35'),
#   rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'),
#   rdflib.term.URIRef('https://swapi.co/vocabulary/Vehicle')),
#  (rdflib.term.URIRef('https://swapi.co/resource/vehicle/72'),
#   rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'),
#   rdflib.term.URIRef('https://swapi.co/vocabulary/Vehicle')),
#  (rdflib.term.URIRef('https://swapi.co/resource/vehicle/16'),
#   rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'),
#   rdflib.term.URIRef('https://swapi.co/vocabulary/Vehicle')),
#  (rdflib.term.URIRef('https://swapi.co/resource/vehicle/26'),
#   rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'),
#   rdflib.term.URIRef('https://swapi.co/vocabulary/Vehicle')),
#  (rdflib.term.URIRef('https://swapi.co/resource/vehicle/4'),
#   rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'),
#   rdflib.term.URIRef('https://swapi.co/vocabulary/Vehicle')),
#  (rdflib.term.URIRef('https://swapi.co/resource/vehicle/50'),
#   rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'),
#   rdflib.term.URIRef('https://swapi.co/vocabulary/Vehicle')),
#  (rdflib.term.URIRef('https://swapi.co/resource/vehicle/51'),
#   rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'),
#   rdflib.term.URIRef('https://swapi.co/vocabulary/Vehicle')),
#  (rdflib.term.URIRef('https://swapi.co/resource/vehicle/19'),
#   rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'),
#   rdflib.term.URIRef('https://swapi.co/vocabulary/Vehicle')),
#  (rdflib.term.URIRef('https://swapi.co/resource/vehicle/44'),
#   rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'),
#   rdflib.term.URIRef('https://swapi.co/vocabulary/Vehicle')),
#  (rdflib.term.URIRef('https://swapi.co/resource/vehicle/7'),
#   rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'),
#   rdflib.term.URIRef('https://swapi.co/vocabulary/Vehicle')),
#  (rdflib.term.URIRef('https://swapi.co/resource/vehicle/34'),
#   rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'),
#   rdflib.term.URIRef('https://swapi.co/vocabulary/Vehicle')),
#  (rdflib.term.URIRef('https://swapi.co/resource/vehicle/36'),
#   rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'),
#   rdflib.term.URIRef('https://swapi.co/vocabulary/Vehicle')),
#  (rdflib.term.URIRef('https://swapi.co/resource/vehicle/60'),
#   rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'),
#   rdflib.term.URIRef('https://swapi.co/vocabulary/Vehicle')),
#  (rdflib.term.URIRef('https://swapi.co/resource/vehicle/33'),
#   rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'),
#   rdflib.term.URIRef('https://swapi.co/vocabulary/Vehicle')),
#  (rdflib.term.URIRef('https://swapi.co/resource/vehicle/8'),
#   rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'),
#   rdflib.term.URIRef('https://swapi.co/vocabulary/Vehicle')),
#  ...]

# %%
query_str = """
    PREFIX rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#>
    PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>
    PREFIX voc: <https://swapi.co/vocabulary/>
    PREFIX xml: <http://www.w3.org/XML/1998/namespace>
    PREFIX xsd: <http://www.w3.org/2001/XMLSchema#>
    PREFIX human: <https://swapi.co/resource/human/>
    
    SELECT ?p
    WHERE {
        human:11 ?p ?u
    }
"""
res = graph.query(query_str)
list(res)
# Out:
# [(rdflib.term.URIRef('https://swapi.co/vocabulary/homeworld')),
#  (rdflib.term.URIRef('https://swapi.co/vocabulary/mass')),
#  (rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#label')),
#  (rdflib.term.URIRef('https://swapi.co/vocabulary/skinColor')),
#  (rdflib.term.URIRef('https://swapi.co/vocabulary/birthYear')),
#  (rdflib.term.URIRef('https://swapi.co/vocabulary/desc')),
#  (rdflib.term.URIRef('https://swapi.co/vocabulary/vehicle')),
#  (rdflib.term.URIRef('https://swapi.co/vocabulary/vehicle')),
#  (rdflib.term.URIRef('https://swapi.co/vocabulary/height')),
#  (rdflib.term.URIRef('https://swapi.co/vocabulary/starship')),
#  (rdflib.term.URIRef('https://swapi.co/vocabulary/film')),
#  (rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type')),
#  (rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type')),
#  (rdflib.term.URIRef('https://swapi.co/vocabulary/starship')),
#  (rdflib.term.URIRef('https://swapi.co/vocabulary/film')),
#  (rdflib.term.URIRef('https://swapi.co/vocabulary/eyeColor')),
#  (rdflib.term.URIRef('https://swapi.co/vocabulary/starship')),
#  (rdflib.term.URIRef('https://swapi.co/vocabulary/film')),
#  (rdflib.term.URIRef('https://swapi.co/vocabulary/gender')),
#  (rdflib.term.URIRef('https://swapi.co/vocabulary/hairColor'))]

# %%
SELECT  ?u
  WHERE
    { da:Noor ^(:p1|!:p1) ?u }

# %%
labels = []
for index, row in dataset.iterrows():
    text = dataset.iloc[index]['text']
    doc = nlp(text)
    print(text)
    for ent in doc.ents:
        print(ent.text, ent.label_)
    print()
# Out:
# Luke Skywalker is a fictional character and the main protagonist of the original film trilogy of the Star Wars franchise created by George Lucas.
# Luke Skywalker PERSON
# George Lucas PERSON
#
# Portrayed by Mark Hamill, Luke first appeared in Star Wars (1977), and he returned in The Empire Strikes Back (1980) and Return of the Jedi (1983).
# Mark Hamill PERSON
# Luke PERSON
# first ORDINAL
# Star Wars ( WORK_OF_ART
# 1977 DATE
# The Empire Strikes Back WORK_OF_ART
# 1980 DATE
# Return of the Jedi WORK_OF_ART
#
# Three decades later, Hamill returned as Luke in the Star Wars sequel trilogy, appearing in all three films: The Force Awakens (2015),
# Three decades later DATE
# Hamill PERSON
# Luke PERSON
# three CARDINAL
# The Force Awakens WORK_OF_ART
# 2015 DATE
#
# The Last Jedi (2017), and The Rise of Skywalker (2019).
# 2017 DATE
# The Rise of Skywalker WORK_OF_ART
# 2019 DATE
#
# He reprised the role in The Mandalorian episode "Chapter 16:
# Chapter 16 LAW
#
# The Rescue" (2020), voicing the character that was portrayed by a body double with digital de-aging.
# 2020 DATE
#
# Originally a farmer on Tatooine living with his uncle and aunt, Luke becomes a pivotal figure in the Rebel Alliance's struggle against the Galactic Empire.
# Tatooine NORP
# Luke PERSON
# the Rebel Alliance's ORG
# the Galactic Empire GPE
#
# The son of fallen Jedi Knight Anakin Skywalker (turned Sith Lord Darth Vader) and Padmé Amidala, Luke is the twin brother of Rebellion leader Princess Leia and eventual brother-in-law of the smuggler Han Solo.
# Jedi Knight Anakin Skywalker PERSON
# Darth Vader PERSON
# Padmé Amidala PERSON
# Luke PERSON
# Rebellion ORG
# Princess Leia PERSON
# Han Solo GPE
#
# Luke trains to be a Jedi under Jedi Masters Obi-Wan Kenobi and Yoda, and rebuilds the Jedi Order.
# Luke PERSON
# Jedi Masters WORK_OF_ART
# Obi-Wan Kenobi PERSON
# Yoda PERSON
# the Jedi Order WORK_OF_ART
#
# He later trains his nephew, Ben Solo, and mentors Rey.
# Ben Solo PERSON
# Rey PERSON
#
# Though Luke dies at the end of The Last Jedi, he returns as a Force spirit in The Rise of Skywalker, encouraging Rey to face her grandfather, the resurrected Darth Sidious.
# Luke PERSON
# the end of The Last DATE
# The Rise of Skywalker WORK_OF_ART
# Rey PERSON
# Darth Sidious PERSON
#
# At the end of the film, the spirits of Luke and Leia give Rey their blessing to adopt the Skywalker surname and continue their family's legacy.
# Luke PERSON
# Leia PERSON
# Rey PERSON
# Skywalker NORP
#
# The character also briefly appears in the prequel film Episode III – Revenge of the Sith as an infant.
#
# In the de-canonized Star Wars Expanded Universe (renamed Legends), Luke is a main character in many stories set after Return of the Jedi, which depict him as a powerful Jedi Master, the husband of Mara Jade, father of Ben Skywalker and maternal uncle of Jaina, Jacen and Anakin Solo.
#
# ===
# Television series ===
# At the end of the Star Wars Rebels episode Twin Suns", a silhouette of Luke Skywalker is seen from afar by Obi-Wan Kenobi.
# Rey PERSON
# Luke PERSON
# Ahch-To WORK_OF_ART
# Yoda PERSON
# Luke PERSON
# Luke PERSON
# Crait PERSON
# First ORDINAL
# Leia PERSON
# Ben PERSON
# Luke PERSON
# First ORDINAL
# Ren PERSON
# Ren PERSON
# Luke PERSON
# Luke PERSON
# Ahch-To WORK_OF_ART
# Luke PERSON
# Crait PERSON
# Luke PERSON
# Kylo PERSON
# Jedi PERSON
# Luke PERSON
# two CARDINAL
# suns ORG
# Force ORG
# 2019 DATE
# Luke PERSON
# The Rise of Skywalker WORK_OF_ART
# ninth ORDINAL
# Rey PERSON
# Darth Sidious PERSON
# Luke PERSON
# Luke PERSON
# Kylo Ren's PERSON
# Luke PERSON
# Rey PERSON
# Luke PERSON
# Rey PERSON
# Luke PERSON
# Rey PERSON
# Palpatine PERSON
# Leia PERSON
# Luke PERSON
# Rey PERSON
# Rey PERSON
# Leia PERSON
# Exegol PERSON
# Rey PERSON
# Tatooine PERSON
# Luke PERSON
# Luke PERSON
# Leia PERSON
# Rey PERSON
# Leia PERSON
# Luke PERSON
# Rey PERSON
# Rey Skywalker PERSON
# Twin Suns ORG
# Luke Skywalker PERSON
# Obi-Wan Kenobi PERSON
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-34-86492542d30e> in <module>
#       2 for index, row in dataset.iterrows():
#       3     text = dataset.iloc[index]['text']
# ----> 4     doc = nlp(text)
#       5     print(text)
#       6     for ent in doc.ents:
#
# ~/miniconda3/envs/entitylink/lib/python3.7/site-packages/spacy/language.py in __call__(self, text, disable, component_cfg)
#     437             if not hasattr(proc, "__call__"):
#     438                 raise ValueError(Errors.E003.format(component=type(proc), name=name))
# --> 439             doc = proc(doc, **component_cfg.get(name, {}))
#     440             if doc is None:
#     441                 raise ValueError(Errors.E005.format(name=name))
#
# pipes.pyx in spacy.pipeline.pipes.EntityLinker.__call__()
#
# pipes.pyx in spacy.pipeline.pipes.EntityLinker.predict()
#
# ~/miniconda3/envs/entitylink/lib/python3.7/site-packages/thinc/neural/_classes/model.py in __call__(self, x)
#     165             Must match expected shape
#     166         """
# --> 167         return self.predict(x)
#     168
#     169     def pipe(self, stream, batch_size=128):
#
# ~/miniconda3/envs/entitylink/lib/python3.7/site-packages/thinc/neural/_classes/feed_forward.py in predict(self, X)
#      38     def predict(self, X):
#      39         for layer in self._layers:
# ---> 40             X = layer(X)
#      41         return X
#      42
#
# ~/miniconda3/envs/entitylink/lib/python3.7/site-packages/thinc/neural/_classes/model.py in __call__(self, x)
#     165             Must match expected shape
#     166         """
# --> 167         return self.predict(x)
#     168
#     169     def pipe(self, stream, batch_size=128):
#
# ~/miniconda3/envs/entitylink/lib/python3.7/site-packages/thinc/check.py in checked_function(wrapped, instance, args, kwargs)
#     151         for arg_id, checks in wrapped.checks.items():
#     152             for check in checks:
# --> 153                 if not isinstance(check, Callable):
#     154                     raise ExpectedTypeError(check, ["Callable"])
#     155                 check(arg_id, fix_args, kwargs)
#
# ~/miniconda3/envs/entitylink/lib/python3.7/abc.py in __instancecheck__(cls, instance)
#     137         def __instancecheck__(cls, instance):
#     138             """Override for isinstance(instance, cls)."""
# --> 139             return _abc_instancecheck(cls, instance)
#     140
#     141         def __subclasscheck__(cls, subclass):
#
# KeyboardInterrupt:

# %%
text = 'Skywalker, also known as Darth Vader, is a fictional character in the Star Wars franchise'
doc = nlp(text)
for ent in doc.ents:
    print(ent.text, ent.label_, ent.kb_id_, str(label_to_name.get(ent.kb_id_)))
