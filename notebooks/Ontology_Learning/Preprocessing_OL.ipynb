# %%
import spacy
from stanfordcorenlp import StanfordCoreNLP
import json
from collections import defaultdict
import nltk
import sys
sys.path.append('../../')
from text_to_graph import process_NER, process_corefs, process_dependency_matching
import pandas as pd
import spacy
import neuralcoref
nlp = spacy.load('en_core_web_lg')

# %%
neuralcoref.add_to_pipe(nlp)
nlp.add_pipe(nlp.create_pipe('sentencizer'))

# %%
doc = nlp('My sister has a dog. She loves him.')

print(doc._.has_coref)
print(doc._.coref_clusters)
print(doc._.coref_resolved)
doc = nlp(doc._.coref_resolved)
sentences = [sent.string.strip() for sent in doc.sents]
print(sentences)
# Out:
# True
# [My sister: [My sister, She], a dog: [a dog, him]]
# My sister has a dog. My sister loves a dog.
# ['My sister has a dog.', 'My sister loves a dog.']

# %%
doc = nlp(u'The cat and the dog sleep in the basket near the door.')
for np in doc.noun_chunks:
    print(np.text)
# Out:
# The cat
# the dog
# the basket
# the door

# %%
raw_text = 'Hello, world. Here are two sentences.'
# nlp.add_pipe(nlp.create_pipe('sentencizer')) # updated
doc = nlp(raw_text)
sentences = [sent.string.strip() for sent in doc.sents]
len(sentences)
# Out:
# 2

# %% [markdown]
# ### Preprocess Unstructured Text Dataset

# %%
dataset = pd.read_csv('./dataset/starwars_text_dataset.txt', delimiter='\n', header=None, error_bad_lines=False)
dataset
# Out:
# b'Skipping line 341: expected 1 fields, saw 2\nSkipping line 1209: expected 1 fields, saw 2\nSkipping line 3309: expected 1 fields, saw 2\nSkipping line 3615: expected 1 fields, saw 2\nSkipping line 7258: expected 1 fields, saw 2\nSkipping line 8720: expected 1 fields, saw 2\nSkipping line 9514: expected 1 fields, saw 2\nSkipping line 11246: expected 1 fields, saw 2\nSkipping line 12019: expected 1 fields, saw 2\nSkipping line 13450: expected 1 fields, saw 2\nSkipping line 15793: expected 1 fields, saw 2\nSkipping line 16472: expected 1 fields, saw 2\nSkipping line 18440: expected 1 fields, saw 2\nSkipping line 20491: expected 1 fields, saw 2\nSkipping line 21737: expected 1 fields, saw 2\nSkipping line 23946: expected 1 fields, saw 2\nSkipping line 24387: expected 1 fields, saw 2\nSkipping line 24930: expected 1 fields, saw 2\nSkipping line 25723: expected 1 fields, saw 2\nSkipping line 26509: expected 1 fields, saw 2\nSkipping line 27150: expected 1 fields, saw 2\nSkipping line 27152: expected 1 fields, saw 2\nSkipping line 27154: expected 1 fields, saw 2\n'
#                                                        0
# 0      Luke Skywalker is a fictional character and th...
# 1      Portrayed by Mark Hamill, Luke first appeared ...
# 2      Three decades later, Hamill returned as Luke i...
# 3      The Last Jedi (2017), and The Rise of Skywalke...
# 4      He reprised the role in The Mandalorian episod...
# ...                                                  ...
# 25145                                      References ==
# 25146                                                 ==
# 25147                                  External links ==
# 25148  Supreme Leader Snoke in the StarWars.com Databank
# 25149            Snoke on Wookieepedia, a Star Wars wiki
#
# [25150 rows x 1 columns]

# %% [markdown]
# ### Preprocessing with CoreNLP

# %%
text = ''
new_text = ''
coref_batch_size = 5
dataset_index = 0
new_dataset = []
keywords = {}
for index, row in dataset.iterrows():
    text += dataset.iloc[index][0]
    if index % coref_batch_size == 0:
        print('Completed Batch: {}'.format(index))
        # Perform Named Entity Recognition with spaCy
        ner_dict = process_NER(text=text)
#         print('***** Completed NER *****')

        # Generate Coreferences and Dependencies with CoreNLP
        corefs = process_corefs(text=text, corenlp_path='../../stanford-corenlp-4.2.0')
#         print("Coreferences found: ", len(corefs))

        # Perform Replacement with Named Entities and Dependencies
        resolved_text = process_dependency_matching(text=text, ner_dict=ner_dict, corefs=corefs)
#         print('***** Completed Coreference Resolution *****')
        #new_text += resolved_text
        
#         print(resolved_text)
        dataset_index = add_to_dataset(resolved_text, dataset_index)
        
        text = ''

# %% [markdown]
# ### Neural Coref

# %%
text = ''
new_text = ''
coref_batch_size = 5
dataset_index = 0
new_dataset = []
keywords = {}
for index, row in dataset.iterrows():
    text += dataset.iloc[index][0]
    if index == 0:
        continue
        
    if index % coref_batch_size == 0:
        doc = nlp(text)
        resolved_text = doc._.coref_resolved
        dataset_index = add_to_dataset(resolved_text, dataset_index)
        text = ''
        print('Completed Batch: {}'.format(index))

# %% [markdown]
# > Grab collections of other sentences and documents for dataset

# %%
def add_to_dataset(resolved_text, dataset_index):
    doc = nlp(resolved_text)
    sentences = [sent.string.strip() for sent in doc.sents]
    for sentence in sentences:
        doc = nlp(sentence)
        # add to keywords
        for np in doc.noun_chunks:
            noun = text_format(np.text)
            if noun not in keywords:
                keywords[noun] = 1
            else:
                keywords[noun] += 1
            # replace keyword in sentence
            sentence = sentence.replace(np.text, noun)
        if len(sentence) < 10:
            continue
        with open("./dataset/starwars_text_dataset_cleanedaa.txt", "a") as file:
            file.write(sentence.lower()  + "\n")
#         new_dataset.append(sentence)
#         dataset.iloc[dataset_index][0] = sentence
        dataset_index += 1
#     print('Dataset Size: {}'.format(dataset_index))
    return dataset_index

# %%
def text_format(text):
    text = text.lower().replace(' ', '_')
    return text

# %%
sentences[7]

# %%
dataset[:10]

# %% [markdown]
# ### Create Keywords

# %%
keywords = {}
for index, row in dataset.iterrows():
    doc = nlp(dataset.iloc[index][0])
    for np in doc.noun_chunks:
        text = text_format(np.text)
        if text not in keywords:
            keywords[text] = 1
        else:
            keywords[text] += 1

# %%
keywords = []
for index, row in dataset.iterrows():
    dataset.iloc[index][0] = dataset.iloc[index][0].lower()
    doc = nlp(dataset.iloc[index][0])
    for ent in doc.ents:
        orig_ent = str(ent)
        ent = orig_ent.replace(' ', '_')
        keywords.append(ent)
        dataset.iloc[index][0] = dataset.iloc[index][0].replace(orig_ent, ent)
    #print(dataset.iloc[index][0])

# %%
for key, value in keywords.items():
    if value < 100:
        continue
    with open("./dataset/starwars_keywords.txt", "a") as file:
        file.write(key  + "\n")

# %%
keywords

# %%
keywords = {k: v for k, v in sorted(keywords.items(), key=lambda item: item[1], reverse=True)}
keywords
# Out:
# {'who': 1526,
#  'it': 1184,
#  'star_wars': 1117,
#  'the_film': 984,
#  'lucas': 861,
#  'luke': 807,
#  'leia': 758,
#  'the_jedi': 754,
#  'the_force': 676,
#  'he': 676,
#  'i': 625,
#  'the_character': 623,
#  'palpatine': 547,
#  'rey': 527,
#  'the_mandalorian': 505,
#  'the_sith': 504,
#  'obi-wan': 489,
#  'anakin': 487,
#  'han': 440,
#  'she': 437,
#  'the_empire': 416,
#  'they': 403,
#  'darth_vader': 397,
#  'the_clone_wars': 386,
#  'return': 377,
#  'revenge': 370,
#  'finn': 343,
#  'chewbacca': 339,
#  'vader': 326,
#  'ren': 309,
#  'the_phantom_menace': 293,
#  'grogu': 288,
#  'the_dark_side': 277,
#  'jabba': 276,
#  'yoda': 263,
#  'lucasfilm': 262,
#  'what': 255,
#  'luke_skywalker': 250,
#  'you': 248,
#  'skywalker': 244,
#  'the_battle': 240,
#  'the_series': 239,
#  'ahsoka': 238,
#  'the_first_order': 234,
#  'the_rise': 232,
#  'the_clones': 229,
#  'the_last_jedi': 223,
#  'attack': 219,
#  'rose': 213,
#  'george_lucas': 211,
#  'him': 210,
#  'c-3po': 206,
#  'we': 206,
#  'the_galaxy': 204,
#  'the_events': 203,
#  'the_resistance': 197,
#  'the_role': 193,
#  'han_solo': 193,
#  'them': 193,
#  'the_republic': 190,
#  'a_new_hope': 188,
#  'order': 180,
#  'padmé': 179,
#  'r2-d2': 178,
#  'part': 178,
#  'her': 176,
#  'the_end': 175,
#  'obi-wan_kenobi': 175,
#  'the_death_star': 174,
#  'the_planet': 174,
#  'naboo': 172,
#  'lando': 170,
#  'kylo_ren': 169,
#  'maul': 168,
#  'december': 164,
#  'bane': 163,
#  'tatooine': 162,
#  'anakin_skywalker': 162,
#  'the_galactic_empire': 158,
#  'poe': 154,
#  'the_hutt': 153,
#  'favreau': 153,
#  'dooku': 150,
#  'tran': 149,
#  'the_millennium_falcon': 147,
#  'the_rebel_alliance': 145,
#  'april': 141,
#  'wookieepedia': 139,
#  'princess_leia': 137,
#  'coruscant': 133,
#  'the_original_trilogy': 131,
#  'thrawn': 131,
#  'qui-gon': 129,
#  'fett': 127,
#  'place': 125,
#  'boba_fett': 125,
#  'cara': 125,
#  'whom': 123,
#  'the_child': 122,
#  'the_star_wars_franchise': 121,
#  'alderaan': 121,
#  'the_franchise': 121,
#  'the_story': 121,
#  'kuiil': 120,
#  'comics': 118,
#  'may': 118,
#  'fans': 117,
#  'ben': 114,
#  'ventress': 113,
#  'jedi': 111,
#  'solo': 110,
#  'the_emperor': 109,
#  'disney': 108,
#  'sidious': 107,
#  'the_galactic_republic': 106,
#  'november': 106,
#  'the_time': 102,
#  'darth_sidious': 101,
#  'darth_maul': 101,
#  'abrams': 100,
#  'gideon': 100,
#  'the_star_wars': 98,
#  'the_new_republic': 98,
#  'endor': 97,
#  'the_star_wars_universe': 97,
#  'external_links': 97,
#  'the_falcon': 97,
#  'chapter': 93,
#  'the_jedi_order': 93,
#  'the_ship': 89,
#  'production': 88,
#  'the_release': 88,
#  'references': 88,
#  'september': 87,
#  'the_rebels': 85,
#  'bib_fortuna': 85,
#  'a_star_wars_story': 84,
#  'march': 84,
#  'snoke': 83,
#  'characters': 83,
#  'fortuna': 83,
#  'mark_hamill': 82,
#  'the_jedi_council': 82,
#  'power': 81,
#  'the_films': 80,
#  'february': 80,
#  'carano': 79,
#  'padmé_amidala': 78,
#  'novels': 78,
#  'star_wars_rebels': 78,
#  'lando_calrissian': 77,
#  'time': 77,
#  'people': 77,
#  'january': 77,
#  'kylo': 76,
#  'rex': 76,
#  'the_united_states': 75,
#  'the_novel': 74,
#  'carrie_fisher': 74,
#  'mayfeld': 74,
#  'himself': 73,
#  'something': 73,
#  'october': 73,
#  'a_jedi': 72,
#  'july': 72,
#  'poe_dameron': 72,
#  'a_fictional_character': 70,
#  'video_games': 70,
#  'the_game': 70,
#  'tarkin': 70,
#  'swallow': 70,
#  'the_name': 69,
#  'august': 69,
#  'cal': 69,
#  'greef': 69,
#  'me': 68,
#  'the_client': 68,
#  'carter': 68,
#  'yavin': 67,
#  'a_character': 67,
#  'filoni': 67,
#  'ben_solo': 66,
#  'scenes': 66,
#  'ezra': 66,
#  'the_show': 66,
#  'jyn': 66,
#  'the_prequel_trilogy': 65,
#  'the_script': 65,
#  'appearances': 64,
#  'the_episode': 64,
#  'the_scene': 64,
#  "qi'ra": 64,
#  'the_armorer': 64,
#  'a_group': 63,
#  'anthony_daniels': 63,
#  'knights': 63,
#  'fisher': 63,
#  'season': 63,
#  'the_droid': 62,
#  'the_rest': 62,
#  'the_old_republic': 62,
#  'a_lot': 62,
#  'the_part': 62,
#  'development': 61,
#  'rebels': 61,
#  'kanan': 61,
#  'windu': 60,
#  'the_jedi_temple': 60,
#  'the_rebellion': 60,
#  'hoth': 59,
#  'ahsoka_tano': 59,
#  'harrison_ford': 59,
#  'jango': 59,
#  'death': 58,
#  'the_voice': 58,
#  'count_dooku': 57,
#  'geonosis': 57,
#  'the_first_season': 57,
#  'episode_iii': 56,
#  'krennic': 56,
#  'the_group': 56,
#  'the_crew': 56,
#  'rogue_one': 56,
#  'phasma': 56,
#  'galen': 56,
#  'june': 55,
#  'weathers': 55,
#  'empire': 54,
#  'films': 54,
#  'episode_ii': 54,
#  'ilm': 54,
#  'jacen': 53,
#  'the_senate': 53,
#  'the_team': 53,
#  'life': 52,
#  'a_pair': 52,
#  'the_destruction': 51,
#  'the_second_death_star': 51,
#  'son': 51,
#  'the_first_time': 51,
#  'battle': 51,
#  'burr': 51,
#  'a_mission': 50,
#  'the_process': 50,
#  'a_playable_character': 50,
#  'the_characters': 50,
#  'the_walt_disney_company': 50,
#  'isbn': 50,
#  'leia_organa': 50,
#  'zannah': 50,
#  'paige': 50,
#  'the_way': 49,
#  'mace_windu': 49,
#  'a_scene': 49,
#  'rogue_squadron': 49,
#  'the_separatists': 48,
#  'star_wars_legends': 48,
#  'the_first_film': 48,
#  'his': 48,
#  'the_movie': 48,
#  'ewan_mcgregor': 48,
#  'critics': 48,
#  'john_williams': 48,
#  'a_number': 47,
#  'all_time': 46,
#  'a_result': 46,
#  'the_set': 46,
#  'the_actor': 46,
#  'a_member': 46,
#  'a_series': 46,
#  'itself': 46,
#  'jakku': 46,
#  'herzog': 46,
#  'billy_dee_williams': 45,
#  'addition': 45,
#  'general_grievous': 45,
#  'kashyyyk': 45,
#  'emperor_palpatine': 44,
#  'the_others': 44,
#  'universe': 44,
#  'rose_tico': 44,
#  'grievous': 44,
#  'wedge': 44,
#  'a_star_wars': 43,
#  'space': 43,
#  'daisy_ridley': 43,
#  'darth_bane': 43,
#  'hayden_christensen': 42,
#  'the_player': 42,
#  'trilogy': 42,
#  'hasbro': 42,
#  'the_second_season': 42,
#  'the_death': 41,
#  'control': 41,
#  'legends': 41,
#  'ign': 41,
#  'john_boyega': 41,
#  'watto': 41,
#  'hux': 41,
#  'the_trade_federation': 41,
#  'george': 40,
#  'ian_mcdiarmid': 40,
#  'someone': 40,
#  'natalie_portman': 40,
#  'the_original_star_wars_trilogy': 39,
#  'the_idea': 39,
#  'the_sequel_trilogy': 39,
#  'others': 39,
#  'the_beginning': 39,
#  'anything': 39,
#  'canada': 39,
#  'a_film': 39,
#  'television': 39,
#  'starkiller_base': 39,
#  'ridley': 39,
#  'iden': 39,
#  'the_adventures': 38,
#  'dathomir': 38,
#  'command': 38,
#  'sith': 38,
#  'lego_star_wars': 38,
#  'johnson': 38,
#  'help': 37,
#  'the_fact': 37,
#  'film': 37,
#  'the_war': 37,
#  'stormtroopers': 37,
#  'greef_karga': 37,
#  'rosas': 37,
#  'a_lightsaber_duel': 36,
#  'episode': 36,
#  'destiny': 36,
#  'love': 36,
#  'screen': 36,
#  'the_production': 36,
#  'mcdiarmid': 36,
#  'j._j._abrams': 36,
#  'the_galactic_senate': 36,
#  'release': 36,
#  'revan': 36,
#  'a_jedi_knight': 35,
#  'the_original_star_wars_film': 35,
#  'the_original_film': 35,
#  'audiences': 35,
#  'the_plans': 35,
#  'clone_troopers': 35,
#  'qui-gon_jinn': 35,
#  'the_order': 35,
#  'the_leader': 35,
#  'the_project': 35,
#  'zahn': 35,
#  'daniels': 35,
#  'supreme_leader_snoke': 34,
#  'character': 34,
#  'peter_mayhew': 34,
#  'magic': 34,
#  'the_first_star_wars_film': 34,
#  'maz': 34,
#  'esposito': 34,
#  'aphra': 34,
#  'a_vision': 33,
#  'evil': 33,
#  'the_location': 33,
#  'the_licensed_star_wars_novels': 33,
#  'lawrence_kasdan': 33,
#  'hamill': 33,
#  'dave_filoni': 33,
#  'the_novelization': 33,
#  'the_world': 33,
#  'the_knights': 33,
#  'peace': 33,
#  'the_scenes': 33,
#  'london': 33,
#  'the_actors': 33,
#  'a_bounty_hunter': 33,
#  'darth_plagueis': 33,
#  'the_costume': 33,
#  'jaina': 32,
#  'cloud_city': 32,
#  'an_attempt': 32,
#  'his_son': 32,
#  'scarif': 32,
#  'a_variety': 32,
#  'war': 32,
#  'the_book': 32,
#  'oscar_isaac': 32,
#  'reviewers': 32,
#  'tie_fighters': 32,
#  'years': 32,
#  'the_old_republic_ii': 32,
#  'creation': 31,
#  'dialogue': 31,
#  'principal_photography': 31,
#  'clone_wars': 31,
#  'lucasarts': 31,
#  'the_attack': 31,
#  'biggs': 31,
#  'the_hollywood_reporter': 31,
#  'cad_bane': 31,
#  'jango_fett': 31,
#  'gerrera': 31,
#  'chirrut': 31,
#  'the_exile': 31,
#  'the_rebel_base': 30,
#  'the_originating_1977_film': 30,
#  'the_sequel': 30,
#  'books': 30,
#  'alec_guinness': 30,
#  'frank_oz': 30,
#  'industrial_light': 30,
#  'post-production': 30,
#  'thousands': 30,
#  'the_fall': 30,
#  'droids': 30,
#  'entertainment_weekly': 30,
#  'bb-8': 30,
#  'los_angeles': 30,
#  'jon_favreau': 30,
#  'piett': 30,
#  'the_son': 29,
#  'birth': 29,
#  'comic_books': 29,
#  'concept': 29,
#  'liam_neeson': 29,
#  'exchange': 29,
#  'marvel_comics': 29,
#  'the_creation': 29,
#  'general_hux': 29,
#  'things': 29,
#  'driver': 29,
#  'the_x-wing': 29,
#  'everything': 29,
#  'chancellor_palpatine': 29,
#  'metacritic': 29,
#  'cara_dune': 29,
#  'boyega': 29,
#  'holdo': 29,
#  'nunb': 29,
#  'the_prequel': 28,
#  'the_lightsaber': 28,
#  'exegol': 28,
#  'the_help': 28,
#  'the_start': 28,
#  'a_way': 28,
#  'adam_driver': 28,
#  'the_confederacy': 28,
#  'the_base': 28,
#  'the_high_republic': 28,
#  'rian_johnson': 28,
#  'the_animated_series': 28,
#  'the_resistance_base': 28,
#  'baby_yoda': 28,
#  'moff_gideon': 28,
#  'crait': 27,
#  'a_jedi_master': 27,
#  'grand_moff_tarkin': 27,
#  'example': 27,
#  'the_same_time': 27,
#  'board': 27,
#  'del_rey': 27,
#  'independent_systems': 27,
#  'mandalore': 27,
#  'lothal': 27,
#  'kathleen_kennedy': 27,
#  'merchandising': 27,
#  'rosenberg': 27,
#  'vos': 27,
#  'aftermath': 27,
#  'the_director': 27,
#  'cassian': 27,
#  'paz': 27,
#  'fear': 26,
#  'an_interview': 26,
#  'the_title': 26,
#  'children': 26,
#  'david_prowse': 26,
#  'the_cast': 26,
#  'forces': 26,
#  'shmi': 26,
#  'the_boy': 26,
#  'the_expanded_universe': 26,
#  'california': 26,
#  'the_screenplay': 26,
#  'members': 26,
#  'combat': 26,
#  'hyperspace': 26,
#  'the_jedithe_jedi': 26,
#  'the_imperial_navy': 26,
#  'jar_jar_binks': 26,
#  'set': 26,
#  'the_original_1977_film': 25,
#  'the_mission': 25,
#  'everyone': 25,
#  'popular_culture': 25,
#  'the_protagonist': 25,
#  'a_child': 25,
#  'anyone': 25,
#  'work': 25,
#  'the_design': 25,
#  'the_star_wars_films': 25,
#  'planets': 25,
#  'bail': 25,
#  'the_plot': 25,
#  'bail_organa': 25,
#  'jyn_erso': 25,
#  'greedo': 25,
#  'mara_jade': 24,
#  "luke's_father": 24,
#  'the_ways': 24,
#  'hiding': 24,
#  '"chapter': 24,
#  'heir': 24,
#  'the_years': 24,
#  'one_point': 24,
#  'james_earl_jones': 24,
#  'the_prequels': 24,
#  'filming': 24,
#  'peter_cushing': 24,
#  'charles_soule': 24,
#  'toys': 24,
#  'the_internet': 24,
#  'del_rey_books': 24,
#  'a_lightsaber': 24,
#  'asajj_ventress': 24,
#  'the_cockpit': 24,
#  'rolling_stone': 24,
#  'the_pilot': 24,
#  'kenny_baker': 24,
#  'kurtz': 24,
#  'portrayal': 24,
#  'kelly_marie_tran': 24,
#  'documentary': 24,
#  'carl_weathers': 24,
#  'the_sin': 24,
#  'cere': 24,
#  'princess_leia_organa': 23,
#  'wedge_antilles': 23,
#  'his_wife': 23,
#  'mustafar': 23,
#  'a_sith_lord': 23,
#  'actors': 23,
#  'an_army': 23,
#  'ben_mendelsohn': 23,
#  'the_season': 23,
#  'light': 23,
#  'advantage': 23,
#  'inspiration': 23,
#  'the_head': 23,
#  'the_people': 23,
#  'ezra_bridger': 23,
#  'serenno': 23,
#  'the_conflict': 23,
#  'the_grand_inquisitor': 23,
#  'lego': 23,
#  'information': 23,
#  'a_pilot': 23,
#  'women': 23,
#  'beckett': 23,
#  'other_star_wars_media': 23,
#  'the_whills': 23,
#  'a_story': 23,
#  'the_united_kingdom': 23,
#  'savage_opress': 23,
#  'the_visual_dictionary': 23,
#  'nevarro': 23,
#  'baze': 23,
#  'howard': 23,
#  'pavan': 23,
#  'janson': 23,
#  'his_father': 22,
#  'a_duel': 22,
#  'a_trap': 22,
#  'front': 22,
#  'a_planet': 22,
#  'jacen_solo': 22,
#  'star_wars_creator_george_lucas': 22,
#  'jake_lloyd': 22,
#  'the_star_wars_expanded_universe': 22,
#  'the_use': 22,
#  'the_third_season': 22,
#  'footage': 22,
#  'steven_spielberg': 22,
#  'other_media': 22,
#  'james_luceno': 22,
#  'an_attack': 22,
#  'action': 22,
#  'the_light_side': 22,
#  'the_2012_acquisition': 22,
#  'wars': 22,
#  'design': 22,
#  'the_trilogy': 22,
#  'the_ground': 22,
#  'none': 22,
#  'themselves': 22,
#  "jabba's_palace": 22,
#  'vanity_fair': 22,
#  'the_sith_lord': 21,
#  'the_temple': 21,
#  'the_hands': 21,
#  'ahch-to': 21,
#  'the_saga': 21,
#  'the_television_series': 21,
#  'sith_lord_count_dooku': 21,
#  'the_prequel_films': 21,
#  'the_future': 21,
#  'american_graffiti': 21,
#  'history': 21,
#  'herself': 21,
#  'the_moment': 21,
#  'the_star_wars_saga': 21,
#  'force': 21,
#  'the_new_york_times': 21,
#  'battle_droids': 21,
#  'disney+': 21,
#  'the_clone_troopers': 21,
#  'a_top_speed': 21,
#  'america': 21,
#  'jar_jar': 21,
#  'isaac': 21,
#  'serkis': 21,
#  'captain_phasma': 21,
#  'misty_rosas': 21,
#  'doctor_aphra': 21,
#  'cobb': 21,
#  'gillen': 21,
#  'the_commander': 20,
#  'force_lightning': 20,
#  'state': 20,
#  'the_force_awakens': 20,
#  'the_audience': 20,
#  'childbirth': 20,
#  'director': 20,
#  'the_guardian': 20,
#  'jinn': 20,
#  'jarrus': 20,
#  'media': 20,
#  'kenobi': 20,
#  'list': 20,
#  'heroes': 20,
#  'cgi': 20,
#  'kennedy': 20,
#  'dark_horse_comics': 20,
#  'the_appearance': 20,
#  'china': 20,
#  'tunisia': 20,
#  'the_craft': 20,
#  'a_list': 20,
#  'the_video_game': 20,
#  'japan': 20,
#  'wicket': 20,
#  'general_leia_organa': 20,
#  'canto_bight': 20,
#  'rosario_dawson': 20,
#  'antilles': 20,
#  'malgus': 20,
#  'obsidian': 20,
#  'the_droids': 19,
#  'star_wars_battlefront_ii': 19,
#  'the_one': 19,
#  'grand_admiral_thrawn': 19,
#  'the_fight': 19,
#  'balance': 19,
#  'christensen': 19,
#  'anger': 19,
#  'response': 19,
#  'the_score': 19,
#  'williams': 19,
#  'the_guardians': 19,
#  'the_term': 19,
#  'a_star_wars_film': 19,
#  'works': 19,
#  'some_critics': 19,
#  'the_course': 19,
#  'ford': 19,
#  'the_surface': 19,
#  'temuera_morrison': 19,
#  'denis_lawson': 19,
#  'dvd': 19,
#  'galaxy': 19,
#  'a_bounty': 19,
#  'marquand': 19,
#  'lyra': 19,
#  'fatherhood': 19,
#  'the_imperials': 19,
#  'mos_eisley': 18,
#  'dagobah': 18,
#  'the_rebel_fleet': 18,
#  'the_spirit': 18,
#  'television_series': 18,
#  'the_unknown_regions': 18,
#  'a_role': 18,
#  'the_original_star_wars': 18,
#  'use': 18,
#  'times': 18,
#  'worlds': 18,
#  'alan_dean_foster': 18,
#  'cultural_impact': 18,
#  'parts': 18,
#  'sources': 18,
#  'episodes': 18,
#  'the_event': 18,
#  'events': 18,
#  'kanan_jarrus': 18,
#  'hope': 18,
#  'computer-generated_imagery': 18,
#  'the_movies': 18,
#  'terms': 18,
#  'casting': 18,
#  'the_washington_post': 18,
#  'the_development': 18,
#  'utapau': 18,
#  'the_tie_fighter': 18,
#  'deflector_shields': 18,
#  'the_mtt': 18,
#  'battlefront': 18,
#  'imperial_troop_transport': 18,
#  'star_destroyers': 18,
#  'the_fighter': 18,
#  "the_film's_release": 18,
#  'cinemascore': 18,
#  'a_plan': 18,
#  'brackett': 18,
#  'australia': 18,
#  'the_actress': 18,
#  'the_reckoning': 18,
#  'original_trilogy': 17,
#  'a_message': 17,
#  'the_crime': 17,
#  'the_thrawn_trilogy': 17,
#  'the_galactic_alliance': 17,
#  'corran_horn': 17,
#  'support': 17,
#  'the_starwars.com': 17,
#  'the_special_edition': 17,
#  'bounty_hunters': 17,
#  'carbonite': 17,
#  'interest': 17,
#  'variety': 17,
#  'the_return': 17,
#  'the_council': 17,
#  'the_ability': 17,
#  'imperial_forces': 17,
#  'a_new_generation': 17,
#  'critical_response': 17,
#  'kevin_j._anderson': 17,
#  'the_company': 17,
#  'shots': 17,
#  'nien_nunb': 17,
#  'resistance': 17,
#  'the_skywalker_saga': 17,
#  'the_filmmakers': 17,
#  'the_1977_film': 17,
#  'shmi_skywalker': 17,
#  'the_2015_film': 17,
#  'a_part': 17,
#  'a_team': 17,
#  'legacy': 17,
#  'trouble': 17,
#  "empire's_end": 17,
#  'search': 17,
#  'andy_serkis': 17,
#  'a_ship': 17,
#  'the_map': 17,
#  'the_duel': 17,
#  'the_pair': 17,
#  'force_arena': 17,
#  'mcgregor': 17,
#  'nothing': 17,
#  'merchandise': 17,
#  'north_america': 17,
#  'rotten_tomatoes': 17,
#  'saw_gerrera': 17,
#  'samuel_l._jackson': 17,
#  'a_sequel': 17,
#  'wookiees': 17,
#  'the_puppet': 17,
#  'the_sith_lords': 17,
#  'disney_ceo_bob_iger': 17,
#  'savage': 17,
#  'the_fifth_brother': 17,
#  'the_mandalorians': 17,
#  'father': 16,
#  'jedi_knights': 16,
#  'the_ewoks': 16,
#  'his_mother': 16,
#  'his_daughter': 16,
#  'the_american_film_institute': 16,
#  'the_form': 16,
#  'the_success': 16,
#  'a_combination': 16,
#  'the_final_scene': 16,
#  'the_planet_tatooine': 16,
#  'the_sith_lord_darth_sidious': 16,
#  'the_power': 16,
#  'the_ghost': 16,
#  'a_brief_appearance': 16,
#  'further_reading': 16,
#  'this_time': 16,
#  'music': 16,
#  'art': 16,
#  'redemption': 16,
#  'the_final_film': 16,
#  'an_apprentice': 16,
#  'the_inquisitors': 16,
#  'a_puppet': 16,
#  'exile': 16,
#  'training': 16,
#  'sound_designer_ben_burtt': 16,
#  'plans': 16,
#  'the_box_office': 16,
#  'the_daughter': 16,
#  'timothy_zahn': 16,
#  'the_forest_moon': 16,
#  'a_battle': 16,
#  'jimmy_smits': 16,
#  'a_great_deal': 16,
#  'the_bounty': 16,
#  'takodana': 16,
#  'amidala': 16,
#  'clones': 16,
#  'ziro': 16,
#  'repulsorlifts': 16,
#  'england': 16,
#  'battlefront_ii': 16,
#  'starfighters': 16,
#  'an_astromech_droid': 16,
#  'the_studio': 16,
#  'new_york': 16,
#  'box_office': 16,
#  'orders': 16,
#  'germany': 16,
#  'ig-11': 16,
#  'tycho_celchu': 16,
#  'mandalorian': 16,
#  'biggs_darklighter': 15,
#  'tusken_raiders': 15,
#  'the_history': 15,
#  'contact': 15,
#  'star_wars_battlefront': 15,
#  'the_main_character': 15,
#  'a_son': 15,
#  'the_new_jedi_order': 15,
#  'the_rank': 15,
#  'a_woman': 15,
#  'a_father': 15,
#  'the_filming': 15,
#  'many_fans': 15,
#  'the_backstory': 15,
#  'his_master': 15,
#  'the_trio': 15,
#  'the_first_death_star': 15,
#  'the_wreckage': 15,
#  'the_season_finale': 15,
#  'star_tours': 15,
#  'appearance': 15,
#  'reception': 15,
#  'chicago': 15,
#  'the_universe': 15,
#  'us': 15,
#  'the_past': 15,
#  'loyalty': 15,
#  'kamino': 15,
#  'joe_johnston': 15,
#  'joonas_suotamo': 15,
#  'calrissian': 15,
#  'episode_iv': 15,
#  'episode_viii': 15,
#  'elements': 15,
#  'maz_kanata': 15,
#  'donald_glover': 15,
#  'fire': 15,
#  'the_weapon': 15,
#  'portman': 15,
#  'the_rule': 15,
#  'the_planet_naboo': 15,
#  'boba': 15,
#  'ralph_mcquarrie': 15,
#  'the_final_cut': 15,
#  'france': 15,
#  'one': 15,
#  'either_side': 15,
#  'the_dialogue': 15,
#  'the_music': 15,
#  'screen_rant': 15,
#  'a_threat': 15,
#  'mother_talzin': 15,
#  'admiral_ackbar': 15,
#  'warwick_davis': 15,
#  'the_quickest_film': 15,
#  'pinewood_studios': 15,
#  'rook': 15,
#  'comic_book_resources': 15,
#  'the_holocron': 15,
#  'giancarlo_esposito': 15,
#  'the_razor_crest': 15,
#  'plagueis': 15,
#  'the_ghost_crew': 15,
#  'a_force_spirit': 14,
#  'imperial_stormtroopers': 14,
#  'owen_lars': 14,
#  'the_nightsisters': 14,
#  'empire_magazine': 14,
#  'number': 14,
#  "ign's_todd_gilchrist": 14,
#  'the_concept': 14,
#  'hundreds': 14,
#  'a_cameo_appearance': 14,
#  'the_conclusion': 14,
#  'mentorship_tree': 14,
#  'the_starwars.com_databank': 14,
#  'the_rights': 14,
#  'indiana_jones': 14,
#  'cartoon_network': 14,
#  'the_style': 14,
#  'half': 14,
#  'company': 14,
#  'fact': 14,
#  'a_handful': 14,
#  'cal_kestis': 14,
#  'a_hyperdrive': 14,
#  'the_galactic_civil_war': 14,
#  'citations': 14,
#  'episode_ix': 14,
#  'strength': 14,
#  'science': 14,
#  'senator_bail_organa': 14,
#  'pirates': 14,
#  'the_heroes': 14,
#  'pressure': 14,
#  'the_subject': 14,
#  "lupita_nyong'o": 14,
#  'matthew_wood': 14,
#  'a_deal': 14,
#  'this_film': 14,
#  'theed': 14,
#  'pre-production': 14,
#  'favor': 14,
#  'starfighter': 14,
#  'pilots': 14,
#  'armor': 14,
#  'dk_publishing': 14,
#  'aspects': 14,
#  'visual_effects': 14,
#  'inflation': 14,
#  'that_time': 14,
#  'ladd': 14,
#  'taylor': 14,
#  'criticism': 14,
#  'treason': 14,
#  'korriban': 14,
#  'players': 14,
#  'mike_quinn': 14,
#  'imax': 14,
#  'twitter': 14,
#  'the_trailer': 14,
#  'felicity_jones': 14,
#  'diego_luna': 14,
#  'galen_erso': 14,
#  'the_first-season_finale': 14,
#  'montross': 14,
#  'bulloch': 14,
#  'the_desert_planet': 13,
#  'senator_padmé_amidala': 13,
#  'twins': 13,
#  'apprentice': 13,
#  'the_art': 13,
#  'the_prophecy': 13,
#  'mara': 13,
#  'victory': 13,
#  'the_new_jedi_order_series': 13,
#  'visions': 13,
#  'darkness': 13,
#  'the_relationship': 13,
#  'games': 13,
#  'the_same_name': 13,
#  'queen': 13,
#  'jedi_master_mace_windu': 13,
#  'kijimi': 13,
#  'ashley_eckstein': 13,
#  'a_slave': 13,
#  'the_star_wars_trilogy': 13,
#  'the_making': 13,
#  'sequels': 13,
#  'theaters': 13,
#  'the_creator': 13,
#  'game': 13,
#  'raiders': 13,
#  'praise': 13,
#  'the_majority': 13,
#  'money': 13,
#  'a_fan': 13,
#  'age': 13,
#  'parents': 13,
#  'a_sith': 13,
#  'master': 13,
#  'the_jedi_starfighter': 13,
#  'the_star_wars_canon': 13,
#  'origin': 13,
#  'elstree_studios': 13,
#  'the_climax': 13,
#  ...}
